# %%
# %load_ext autoreload
# %autoreload 2  # Autoreload all modules
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# libs
import glob
import pandas as pd
import random
import pprint
pp = pprint.PrettyPrinter(indent=4)
#import importlib

import itertools
from collections import Counter
from collections import OrderedDict
import matplotlib.pyplot as plt
import numpy as np

from nltk import sent_tokenize
from nltk.tokenize import word_tokenize

import networkx as nx

from tqdm import tqdm

# perso
import sys
sys.path.append('utils/')
sys.path.append('argdisc/')

sys.path.insert(1, '/Users/lhuber/Documents/Research/Phd/workdir/SciDTB/code/probing/')

from data_mgmt import *
from graphs_utils import *
from moves_utils import *
from corpus_utils import Corpus
from preprocessing_utils import *
from arg_ana import *
from arg_disc_ana import *
from gspan import *

# %% [markdown]
# # Load Data

# %%
# Import corpus to dataframe (text and units)

# the corpus is organized following 3 directories
# in each directory, some files are annotated by multiple annotators
# we take all the uniq documents (just 1 annotator)
pathtodirtrain = "data/train/"
pathtodirtest  = "data/test/gold/"
pathtodirdev   = "data/dev/gold/"
#pathtographs   = "../data/SciDTB/graphimages/"
#path2properties = "../data/SciDTB_articles_properties.csv"


# considere only 1 annotator (taken randomly)
allano = "*.dep"
files = glob.glob(pathtodirtrain+allano) # for train keep only one annotator
# remove duplicate documents (other annotators)
files = [x for x in files if "anno2" not in x and "anno3" not in x] 
files += glob.glob(pathtodirtest+allano)
files += glob.glob(pathtodirdev+allano)

c = Corpus(files=files)

# %%
arg_annots = "data/scidtb_argmin_annotations/*.conll.good"
basename = "data/scidtb_argmin_annotations/"
endname = "-fexp-corpus.conll.good"
arg_files = [x for x in glob.glob(arg_annots)]

docs = []
for file in arg_files:
    docname = file.replace(basename, "")
    docname = docname.replace(endname, "")
    docs.append(docname)
    
argdiscdtf = c.corpus.loc[docs]

# %%
argdiscdtf["arg_annot"] = argdiscdtf.apply(lambda x: get_arg_annot(basename+x.name+endname), axis=1)
argdiscdtf["arg_graph"] = argdiscdtf.apply(lambda x: get_arg_graph(x.arg_annot), axis=1)
argdiscdtf["arg_sents"] = argdiscdtf.apply(lambda x: get_arg_sents(get_arg_annot(basename+x.name+endname)), axis=1)
argdiscdtf["segtxt"] = argdiscdtf.apply(lambda row: preprocess(row.segments), axis=1)
argdiscdtf["argtxt"] = argdiscdtf.apply(lambda row: preprocess(row.arg_sents), axis=1)
argdiscdtf["edus_adus_mapping"] = argdiscdtf.apply(lambda row: to_edus_adus_mapping(row.argtxt, row.segtxt), axis=1)
argdiscdtf["adus_edus_mapping"] = argdiscdtf.apply(lambda row: remove_nones(to_adus_edus_mapping(row.edus_adus_mapping)), axis=1)
argdiscdtf["sents_edus_mapping"] = argdiscdtf.apply(lambda row: to_sent_edus_mapping(row.edus_sent_ids), axis=1)
docnames = argdiscdtf.index.to_list()

# %% [markdown]
# # Data Preparation

# %%
adusentdtf = argdiscdtf[["segments", "edus_adus_mapping", 
                         "adus_edus_mapping", "sents_edus_mapping"]]

# %% [markdown]
# ## Prepare Arg / Sent data

# %%
adusentdtf["has_sim_arg_sent"] = adusentdtf.apply(lambda row: has_sim_seg(row.adus_edus_mapping, row.sents_edus_mapping), axis=1)
adusentdtf["sim_arg_sent"] = adusentdtf.apply(lambda row: sim_seg(row.adus_edus_mapping, row.sents_edus_mapping), axis=1)
adusentdtf["prop_sim_arg_sent"] = adusentdtf.apply(lambda row: prop_sim_seg(row.sim_arg_sent), axis=1)

# %%
notmapped = adusentdtf[adusentdtf["prop_sim_arg_sent"] != 1]

# %%
notmapped = notmapped[["adus_edus_mapping", "sents_edus_mapping", "sim_arg_sent"]]

# %%
notmapped["notmapped_args"] = notmapped.apply(lambda row: {k:v for k,v in row.sim_arg_sent.items() if v == False}, axis=1)

# %%
notmapped["notmapped_args"] = notmapped.apply(lambda row: {k: row.adus_edus_mapping[k] for k,v in row.notmapped_args.items()}, axis=1)

# %% [markdown]
# # Prepare Type data

# %%
typedtf = argdiscdtf[["adus_edus_mapping", "graph"]]

# %%
typedtf["arg_annot"] = argdiscdtf["arg_annot"]

# %%
typedtf["arg_types"] = typedtf.apply(lambda x: get_arg_types(x.arg_annot), axis=1)

# %%
typedtf["arg_subs"] = typedtf.apply(lambda x: get_arg_subs(x.adus_edus_mapping, x.graph), axis=1)

# %%
assert [len(x) for x in typedtf["arg_types"]] == [len(x) for x in typedtf["arg_subs"]]

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Arg / Sent segments boundaries analysis

# %% [markdown]
# ### Number of args that do not map with sentence

# %%
sum([len(x) for x in notmapped["notmapped_args"]])
# Out:
# 59

# %% [markdown]
# ### Calculate arg and sentence mapping

# %%
sents = list(notmapped["sents_edus_mapping"])
adus = list(notmapped["notmapped_args"])
docnames = notmapped.index.to_list()
sent_mappings = [get_sent_mapping(a,s) for a,s in zip(adus, sents)]
arg_mappings = [get_adu_mapping(a,s) for a,s in zip(adus, sents)]

# %% [markdown]
# ### Args bigger than sentences

# %%
for i, d in enumerate(arg_mappings):
    if d != {}:
        print(docnames[i])
        print(d)
# Out:
# D14-1043
# {0: [0, 1]}
# D14-1020
# {1: [1, 2]}

# %% [markdown]
# ### Sentences bigger then args

# %% [markdown]
# #### Plot distrib len sents (in nb of edus) global

# %%
all_args_edus = [list(doc.values()) for doc in list(adusentdtf["sents_edus_mapping"])]

# %%
all_args_edus_lens = [len(x) for doc in all_args_edus for x in doc]

# %%
plt.hist(all_args_edus_lens)
# Out:
# (array([ 65., 120.,  75.,  38.,   0.,  15.,  11.,   4.,   0.,   2.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. , 5.8, 6.6, 7.4, 8.2, 9. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #### Vs distrib len sents (in nb of edus) for sentences having than 1 arg

# %%
## Calculate number of edus for each sentence made of more than 1 argument
nb_edus_sent_mapping = []
edus_sent_mapping = []
docs = []
for i, smap in enumerate(sent_mappings):
    doc = docnames[i]
    if smap != {}:
        #print(sents[i][])
        for sid, sent in smap.items():
            docs.append(docnames[i])
            nb_edus_sent_mapping.append(len(sents[i][sid]))
            edus_sent_mapping.append((doc, sents[i][sid]))

# %%
Counter(nb_edus_sent_mapping)
# Out:
# Counter({6: 6, 4: 2, 3: 8, 5: 4, 2: 9, 7: 1})

# %%
plt.hist(nb_edus_sent_mapping)
# Out:
# (array([9., 0., 8., 0., 2., 0., 4., 0., 6., 1.]),
#  array([2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Argumentation discourse structure analysis

# %%
mappings = argdiscdtf["adus_edus_mapping"]
graphs = argdiscdtf.graph

# %%
mappings = argdiscdtf["adus_edus_mapping"]
graphs = argdiscdtf.graph
macrographs = [get_arg_macrog(m, g) for m,g in zip(mappings, graphs)]
arggraphs = [get_arg_graph(x) for x in argdiscdtf["arg_annot"]]

# %% [markdown]
# ### Structure

# %%
macrocomp = pd.DataFrame({"arggraph": arggraphs,
                          "discmacrograph": macrographs})

# %%
macrocomp["sim_dirrels"] = macrocomp.apply(lambda row: prop_sim_rels(row.arggraph, row.discmacrograph, direc=True), axis=1)
macrocomp["sim_rels"] = macrocomp.apply(lambda row: prop_sim_rels(row.arggraph, row.discmacrograph), axis=1)
macrocomp["sim_labrels"] = macrocomp.apply(lambda row: prop_sim_rels(row.arggraph, row.discmacrograph, labels=True), axis=1)

# %% [markdown]
# #### Undirected

# %%
macrocomp["sim_rels"].describe()
# Out:
# count    60.000000
# mean      0.772579
# std       0.194196
# min       0.250000
# 25%       0.666667
# 50%       0.750000
# 75%       1.000000
# max       1.000000
# Name: sim_rels, dtype: float64

# %% [markdown]
# #### Directed

# %%
macrocomp["sim_dirrels"].describe()
# Out:
# count    60.000000
# mean      0.668135
# std       0.261377
# min       0.000000
# 25%       0.500000
# 50%       0.666667
# 75%       1.000000
# max       1.000000
# Name: sim_dirrels, dtype: float64

# %% [markdown]
# ### Labels

# %%
mappings = [rels_mapping(mg, ag) for mg, ag in zip(macrographs, arggraphs)]
merged_map = merge_dict(mappings)
merge_map_count = {k: dict(Counter(flat(v))) for k,v in merged_map.items()}

# %%
merge_map_count
# Out:
# {'elab-addition': {'detail': 25, 'support': 11},
#  'elab-process_step': {'detail': 7},
#  'evaluation': {'detail': 1, 'support': 47},
#  'result': {'additional': 4, 'detail': 1, 'support': 1},
#  'bg-goal': {'support': 10},
#  'elab-aspect': {'detail': 22, 'support': 4},
#  'progression': {'detail': 6},
#  'manner-means': {'detail': 18, 'support': 1},
#  'joint': {'detail': 4},
#  'bg-compare': {'support': 8},
#  'bg-general': {'support': 2, 'detail': 1},
#  'summary': {'detail': 1, 'support': 1},
#  'exp-evidence': {'support': 5},
#  'enablement': {'detail': 1},
#  'exp-reason': {'detail': 1},
#  'contrast': {'additional': 3},
#  'elab-example': {'detail': 1},
#  'attribution': {'detail': 1},
#  'cause': {'additional': 1},
#  'elab-enum_member': {'detail': 1}}

# %% [markdown]
# #### Elab-addition

# %%
docs_with_elab_add = []
for docname, m in zip(docnames, mappings):
    if "elab-addition" in m.keys():
        docs_with_elab_add.append(docname)

# %%
argdiscdtf["disc_macro_graph"] = macrographs 
elabdtf = argdiscdtf.loc[docs_with_elab_add]
elabdtf = elabdtf[["arg_graph", "graph", "disc_macro_graph"]]

# %% [markdown]
# #### Distrib mapping based on position in tree

# %%
root_rels = []
for doc, gphs in elabdtf.iterrows():
    arg = gphs["arg_graph"]
    disc = gphs["disc_macro_graph"]
    root_rels.append(elab_root_rels(arg, disc))
#print(root_rels)
elabdtf["root_elabs"] = root_rels

# %%
elabdtf["root_elabs"]
# Out:
# docname
# D14-1045           []
# D14-1002           []
# D14-1041       [None]
# D14-1034     [detail]
# D14-1024    [support]
# D14-1056     [detail]
# D14-1052     [detail]
# D14-1016           []
# Name: root_elabs, dtype: object

# %% [markdown]
# #### Distrib mapping based on relation sequence

# %%
#for doc, gphs in elabdtf.iterrows():
    #print(doc)
    #draw_graph(gphs["arg_graph"])
    #draw_graph(gphs["disc_macro_graph"])

# %% [markdown]
# ## Argumentation type analysis

# %%
args_per_type = {}
for subs, types in zip(typedtf["arg_subs"], typedtf["arg_types"]):
    for sub, typ in zip(subs, types):
        if typ not in args_per_type.keys():
            args_per_type[typ] = [sub]
        else:
            args_per_type[typ].append(sub)

# %% [markdown]
# ### Nb args of each type

# %%
for k, subs in args_per_type.items():
    print(k)
    print(len(subs))
# Out:
# proposal
# 110
# description
# 7
# means
# 63
# observation
# 11
# assertion
# 88
# result
# 74

# %% [markdown]
# ### Distrib len per type

# %%
types_lens = {k:[len(x.nodes) for x in v] for k,v in args_per_type.items()}
arrays = types_lens.values()

# %%
n_bins=6

# %%
colors = ['blue', 'orange', 'green', "yellow", "red", "pink"]
names = list(types_lens.keys())

# %%
plt.hist(arrays, n_bins, histtype='bar', label=names)
plt.legend(loc="upper right")
plt.title('Distrib arg length per type')
plt.show()

# %% [markdown]
# ### Distrib rels per type

# %%
type_rels_temp = {k:[list(x.edges(data=True)) for x in v] for k,v in args_per_type.items()}
type_rels = {}
for k, docv in type_rels_temp.items():
    type_rels[k] = []
    #print(v)
    for v in docv:
        for edge in v:
            #print(edge)
            type_rels[k].append(edge[2]["label"])

# %%
type_rels_temp = {k:[list(x.edges(data=True)) for x in v] for k,v in args_per_type.items()}
nb_rels_doc = {}
for k, docv in type_rels_temp.items():
    nb_rels_doc[k] = []
    #print(v)
    for v in docv:
        #print(v)
        nb_rels_doc[k].append(len(v))
    nb_rels_doc[k] = np.mean(nb_rels_doc[k])

# %%
nb_rels_doc
# Out:
# {'proposal': 1.6,
#  'description': 1.0,
#  'means': 1.1904761904761905,
#  'observation': 0.45454545454545453,
#  'assertion': 1.3295454545454546,
#  'result': 1.6891891891891893}

# %% [markdown]
# #### Nb rels
# /!\ Certains types ont moins de rels que de EDUs, c'est lorsque des args sont composés d'une seule edu

# %%
for k, rels in type_rels.items():
    print(k)
    print(len(rels))
# Out:
# proposal
# 176
# description
# 7
# means
# 75
# observation
# 5
# assertion
# 117
# result
# 125

# %%
### Distrib rels per type

# %%
type_rels_cnt = {k:Counter(v) for k,v in type_rels.items()}

# %%
type_rels_cnt
# Out:
# {'proposal': Counter({'enablement': 36,
#           'progression': 9,
#           'elab-enum_member': 6,
#           'elab-addition': 69,
#           'contrast': 9,
#           'manner-means': 16,
#           'temporal': 3,
#           'bg-general': 4,
#           'elab-example': 5,
#           'joint': 10,
#           'same-unit': 1,
#           'attribution': 4,
#           'cause': 1,
#           'condition': 1,
#           'result': 1,
#           'comparison': 1}),
#  'description': Counter({'elab-example': 1,
#           'elab-addition': 5,
#           'elab-enum_member': 1}),
#  'means': Counter({'manner-means': 6,
#           'enablement': 21,
#           'joint': 13,
#           'bg-general': 3,
#           'elab-addition': 24,
#           'elab-enum_member': 1,
#           'exp-reason': 1,
#           'attribution': 1,
#           'progression': 1,
#           'elab-example': 1,
#           'same-unit': 2,
#           'contrast': 1}),
#  'observation': Counter({'elab-addition': 2,
#           'manner-means': 1,
#           'comparison': 1,
#           'joint': 1}),
#  'assertion': Counter({'manner-means': 4,
#           'elab-addition': 35,
#           'same-unit': 6,
#           'condition': 5,
#           'enablement': 10,
#           'contrast': 8,
#           'elab-example': 3,
#           'joint': 20,
#           'temporal': 2,
#           'elab-aspect': 3,
#           'progression': 3,
#           'attribution': 7,
#           'bg-general': 2,
#           'exp-reason': 5,
#           'result': 2,
#           'comparison': 2}),
#  'result': Counter({'attribution': 40,
#           'joint': 11,
#           'elab-aspect': 1,
#           'temporal': 4,
#           'elab-addition': 28,
#           'same-unit': 8,
#           'exp-reason': 1,
#           'enablement': 7,
#           'manner-means': 8,
#           'elab-enum_member': 2,
#           'progression': 3,
#           'bg-general': 5,
#           'condition': 2,
#           'comparison': 3,
#           'contrast': 1,
#           'elab-example': 1})}

# %% [markdown]
# ### Distrib rels seqs per type

# %%
for k, v in args_per_type.items():
    print(k)
    draw_graph(v[0])
# Out:
# proposal
# description
# means
# observation
# assertion
# result

# %%
args_per_type_gspan_out = {k:gspan(v, 1, 2, method=3) for k,v in args_per_type.items()}

# %%
all_args = list(args_per_type.values())
all_args = [item for sublist in all_args for item in sublist]

# %%
all_args_gspan_out = gspan(all_args, 1, 2, method=2)

# %%
def objs(outgspan):
    objs = list(outgspan["isomorph_graphs"])
    objs = [item for sublist in objs for item in sublist]
    return objs

# %%
def nb_graphs_having_rel(relname, graphs):
    cnt=0
    for g in graphs:
        labels = [x[2]["label"] for x in g.edges(data=True)]
        if relname in labels:
            cnt+=1
    return cnt

# %% [markdown]
# ### Subgraph analysis : focus on proposal/means/assertion/result

# %% [markdown]
# ### Can we distinguish proposal from assertion ?

# %%
len(set(objs(all_args_gspan_out[1])))
# Out:
# 263

# %%
all_out = all_args_gspan_out
assert_out = args_per_type_gspan_out["assertion"][1]
prop_out = args_per_type_gspan_out["proposal"][1]
means_out = args_per_type_gspan_out["means"][1]
result_out = args_per_type_gspan_out["result"][1]
obs_out = args_per_type_gspan_out["observation"][1]
descr_out = args_per_type_gspan_out["description"][1]

# %%
descr_out
# Out:
#    support                                             graph  \
# 1        1  <gspan_mining.graph.Graph object at 0x133628c10>
# 2        4  <gspan_mining.graph.Graph object at 0x133628c90>
# 3        1  <gspan_mining.graph.Graph object at 0x1335d7810>
# 4        1  <gspan_mining.graph.Graph object at 0x1335e5190>
# 5        1  <gspan_mining.graph.Graph object at 0x1335ee7d0>
# 6        1  <gspan_mining.graph.Graph object at 0x1335e5e90>
#
#                                             graphstr  num_vert isomorph_graphs
# 1                    v 0 X v 1 X e 0 1 elab-example          2             [0]
# 2                   v 0 X v 1 X e 0 1 elab-addition          2    [0, 1, 2, 6]
# 3  v 0 X v 1 X v 2 X e 0 1 elab-addition e 1 2 el...         3             [0]
# 4  v 0 X v 1 X v 2 X e 0 1 elab-addition e 1 2 el...         3             [2]
# 5  v 0 X v 1 X v 2 X e 0 1 elab-addition e 1 2 el...         3             [6]
# 6                v 0 X v 1 X e 0 1 elab-enum_member          2             [2]

# %%
obs_out
# Out:
#    support                                             graph  \
# 1        2  <gspan_mining.graph.Graph object at 0x132eff0d0>
# 2        1  <gspan_mining.graph.Graph object at 0x133379110>
# 3        1  <gspan_mining.graph.Graph object at 0x1335c1490>
# 4        1  <gspan_mining.graph.Graph object at 0x1335ff950>
# 5        1  <gspan_mining.graph.Graph object at 0x1335c1e90>
#
#                                             graphstr  num_vert isomorph_graphs
# 1                   v 0 X v 1 X e 0 1 elab-addition          2          [0, 6]
# 2                    v 0 X v 1 X e 0 1 manner-means          2             [3]
# 3                      v 0 X v 1 X e 0 1 comparison          2             [6]
# 4  v 0 X v 1 X v 2 X e 0 1 comparison e 1 2 elab-...         3             [6]
# 5                           v 0 X v 1 X e 0 1 joint          2             [8]

# %%
result_out.sort_values(by="support", ascending=False)
# Out:
#      support                                             graph  \
# 1         40  <gspan_mining.graph.Graph object at 0x1339001d0>
# 64        24  <gspan_mining.graph.Graph object at 0x133948e50>
# 6         12  <gspan_mining.graph.Graph object at 0x133913590>
# 56        10  <gspan_mining.graph.Graph object at 0x1339050d0>
# 111        8  <gspan_mining.graph.Graph object at 0x1339b4750>
# ..       ...                                               ...
# 53         1  <gspan_mining.graph.Graph object at 0x133920ed0>
# 52         1  <gspan_mining.graph.Graph object at 0x133977950>
# 51         1  <gspan_mining.graph.Graph object at 0x133977210>
# 50         1  <gspan_mining.graph.Graph object at 0x13396c350>
# 131        1  <gspan_mining.graph.Graph object at 0x1339c3a10>
#
#                                               graphstr  num_vert  \
# 1                       v 0 X v 1 X e 0 1 attribution          2
# 64                    v 0 X v 1 X e 0 1 elab-addition          2
# 6    v 0 X v 1 X v 2 X e 0 1 attribution e 1 2 elab...         3
# 56                            v 0 X v 1 X e 0 1 joint          2
# 111                    v 0 X v 1 X e 0 1 manner-means          2
# ..                                                 ...       ...
# 53   v 0 X v 1 X v 2 X v 3 X v 4 X e 0 1 attributio...         5
# 52   v 0 X v 1 X v 2 X v 3 X e 0 1 attribution e 1 ...         4
# 51   v 0 X v 1 X v 2 X e 0 1 attribution e 1 2 cont...         3
# 50   v 0 X v 1 X v 2 X e 0 1 attribution e 1 2 comp...         3
# 131                    v 0 X v 1 X e 0 1 elab-example          2
#
#                                        isomorph_graphs
# 1    [0, 1, 2, 3, 4, 6, 7, 9, 16, 18, 19, 20, 22, 2...
# 64   [3, 5, 6, 7, 10, 12, 15, 22, 27, 29, 30, 31, 3...
# 6       [32, 3, 67, 37, 6, 73, 63, 53, 27, 29, 30, 31]
# 56                [65, 2, 58, 5, 6, 7, 42, 13, 22, 26]
# 111                     [32, 66, 37, 7, 8, 44, 45, 61]
# ..                                                 ...
# 53                                                [63]
# 52                                                [63]
# 51                                                [63]
# 50                                                [52]
# 131                                               [71]
#
# [131 rows x 5 columns]

# %%
means_out.sort_values(by="support", ascending=False)
# Out:
#     support                                             graph  \
# 3        18  <gspan_mining.graph.Graph object at 0x1335d7050>
# 19       17  <gspan_mining.graph.Graph object at 0x13355b150>
# 12       11  <gspan_mining.graph.Graph object at 0x108d1c7d0>
# 23        7  <gspan_mining.graph.Graph object at 0x133350490>
# 1         6  <gspan_mining.graph.Graph object at 0x1335699d0>
# 4         5  <gspan_mining.graph.Graph object at 0x13352e350>
# 20        4  <gspan_mining.graph.Graph object at 0x13352ec90>
# 28        3  <gspan_mining.graph.Graph object at 0x1335f5150>
# 16        3  <gspan_mining.graph.Graph object at 0x1335b1690>
# 8         2  <gspan_mining.graph.Graph object at 0x1335076d0>
# 47        2  <gspan_mining.graph.Graph object at 0x133608810>
# 13        2  <gspan_mining.graph.Graph object at 0x133537750>
# 22        2  <gspan_mining.graph.Graph object at 0x1335157d0>
# 39        2  <gspan_mining.graph.Graph object at 0x1338124d0>
# 33        1  <gspan_mining.graph.Graph object at 0x133819590>
# 34        1  <gspan_mining.graph.Graph object at 0x133843a10>
# 36        1  <gspan_mining.graph.Graph object at 0x1337f4490>
# 37        1  <gspan_mining.graph.Graph object at 0x1337e0cd0>
# 35        1  <gspan_mining.graph.Graph object at 0x133515c50>
# 40        1  <gspan_mining.graph.Graph object at 0x1337e7a90>
# 38        1  <gspan_mining.graph.Graph object at 0x1337c3950>
# 31        1  <gspan_mining.graph.Graph object at 0x1335ff490>
# 41        1  <gspan_mining.graph.Graph object at 0x13354ff90>
# 42        1  <gspan_mining.graph.Graph object at 0x13354fcd0>
# 43        1  <gspan_mining.graph.Graph object at 0x1338123d0>
# 44        1  <gspan_mining.graph.Graph object at 0x1335ff3d0>
# 45        1  <gspan_mining.graph.Graph object at 0x13354f8d0>
# 46        1  <gspan_mining.graph.Graph object at 0x133843e50>
# 32        1  <gspan_mining.graph.Graph object at 0x133832850>
# 25        1  <gspan_mining.graph.Graph object at 0x13352e190>
# 30        1  <gspan_mining.graph.Graph object at 0x13352e4d0>
# 29        1  <gspan_mining.graph.Graph object at 0x133195c10>
# 5         1  <gspan_mining.graph.Graph object at 0x13354f090>
# 6         1  <gspan_mining.graph.Graph object at 0x13354f7d0>
# 7         1  <gspan_mining.graph.Graph object at 0x133537290>
# 9         1  <gspan_mining.graph.Graph object at 0x13354f0d0>
# 10        1  <gspan_mining.graph.Graph object at 0x1335b1490>
# 11        1  <gspan_mining.graph.Graph object at 0x1335b1190>
# 14        1  <gspan_mining.graph.Graph object at 0x13352e6d0>
# 15        1  <gspan_mining.graph.Graph object at 0x1337ec510>
# 17        1  <gspan_mining.graph.Graph object at 0x13336b990>
# 18        1  <gspan_mining.graph.Graph object at 0x1337b6f10>
# 21        1  <gspan_mining.graph.Graph object at 0x133537790>
# 24        1  <gspan_mining.graph.Graph object at 0x1337d9590>
# 2         1  <gspan_mining.graph.Graph object at 0x1335376d0>
# 26        1  <gspan_mining.graph.Graph object at 0x13337ccd0>
# 27        1  <gspan_mining.graph.Graph object at 0x1338322d0>
# 48        1  <gspan_mining.graph.Graph object at 0x133819290>
#
#                                              graphstr  num_vert  \
# 3                       v 0 X v 1 X e 0 1 enablement          2
# 19                   v 0 X v 1 X e 0 1 elab-addition          2
# 12                           v 0 X v 1 X e 0 1 joint          2
# 23  v 0 X v 1 X v 2 X e 0 1 elab-addition e 1 2 en...         3
# 1                     v 0 X v 1 X e 0 1 manner-means          2
# 4     v 0 X v 1 X v 2 X e 0 1 enablement e 1 2 joint          3
# 20  v 0 X v 1 X v 2 X e 0 1 elab-addition e 1 2 jo...         3
# 28  v 0 X v 1 X v 2 X e 0 1 elab-addition e 1 2 el...         3
# 16                      v 0 X v 1 X e 0 1 bg-general          2
# 8   v 0 X v 1 X v 2 X v 3 X e 0 1 enablement e 1 2...         4
# 47                       v 0 X v 1 X e 0 1 same-unit          2
# 13  v 0 X v 1 X v 2 X e 0 1 joint e 1 2 manner-means          3
# 22  v 0 X v 1 X v 2 X v 3 X e 0 1 elab-addition e ...         4
# 39  v 0 X v 1 X v 2 X e 0 1 elab-addition e 1 2 sa...         3
# 33  v 0 X v 1 X v 2 X v 3 X e 0 1 elab-addition e ...         4
# 34  v 0 X v 1 X v 2 X v 3 X v 4 X e 0 1 elab-addit...         5
# 36  v 0 X v 1 X v 2 X v 3 X v 4 X v 5 X v 6 X e 0 ...         7
# 37  v 0 X v 1 X v 2 X v 3 X v 4 X v 5 X e 0 1 elab...         6
# 35  v 0 X v 1 X v 2 X v 3 X v 4 X v 5 X e 0 1 elab...         6
# 40                v 0 X v 1 X e 0 1 elab-enum_member          2
# 38  v 0 X v 1 X v 2 X v 3 X v 4 X e 0 1 elab-addit...         5
# 31  v 0 X v 1 X v 2 X v 3 X v 4 X v 5 X e 0 1 elab...         6
# 41                      v 0 X v 1 X e 0 1 exp-reason          2
# 42                     v 0 X v 1 X e 0 1 attribution          2
# 43   v 0 X v 1 X v 2 X e 0 1 attribution e 1 2 joint          3
# 44  v 0 X v 1 X v 2 X v 3 X e 0 1 attribution e 1 ...         4
# 45                     v 0 X v 1 X e 0 1 progression          2
# 46                    v 0 X v 1 X e 0 1 elab-example          2
# 32  v 0 X v 1 X v 2 X v 3 X e 0 1 elab-addition e ...         4
# 25  v 0 X v 1 X v 2 X v 3 X v 4 X e 0 1 elab-addit...         5
# 30  v 0 X v 1 X v 2 X v 3 X v 4 X e 0 1 elab-addit...         5
# 29  v 0 X v 1 X v 2 X v 3 X e 0 1 elab-addition e ...         4
# 5   v 0 X v 1 X v 2 X v 3 X e 0 1 enablement e 1 2...         4
# 6   v 0 X v 1 X v 2 X v 3 X v 4 X e 0 1 enablement...         5
# 7   v 0 X v 1 X v 2 X v 3 X v 4 X v 5 X e 0 1 enab...         6
# 9   v 0 X v 1 X v 2 X v 3 X v 4 X e 0 1 enablement...         5
# 10  v 0 X v 1 X v 2 X v 3 X e 0 1 enablement e 1 2...         4
# 11  v 0 X v 1 X v 2 X v 3 X e 0 1 enablement e 1 2...         4
# 14  v 0 X v 1 X v 2 X v 3 X e 0 1 joint e 1 2 mann...         4
# 15         v 0 X v 1 X v 2 X e 0 1 joint e 1 2 joint          3
# 17  v 0 X v 1 X v 2 X e 0 1 bg-general e 1 2 enabl...         3
# 18  v 0 X v 1 X v 2 X e 0 1 bg-general e 1 2 contr...         3
# 21  v 0 X v 1 X v 2 X v 3 X e 0 1 elab-addition e ...         4
# 24  v 0 X v 1 X v 2 X v 3 X e 0 1 elab-addition e ...         4
# 2   v 0 X v 1 X v 2 X e 0 1 manner-means e 1 2 pro...         3
# 26  v 0 X v 1 X v 2 X v 3 X e 0 1 elab-addition e ...         4
# 27  v 0 X v 1 X v 2 X v 3 X e 0 1 elab-addition e ...         4
# 48                        v 0 X v 1 X e 0 1 contrast          2
#
#                                       isomorph_graphs
# 3   [1, 3, 4, 35, 36, 37, 8, 41, 10, 11, 42, 13, 1...
# 19  [35, 38, 39, 8, 9, 41, 11, 12, 13, 14, 49, 18,...
# 12          [3, 38, 7, 8, 40, 41, 48, 19, 53, 23, 62]
# 23                       [35, 41, 11, 13, 14, 24, 58]
# 1                               [0, 3, 5, 22, 23, 25]
# 4                                  [3, 8, 41, 48, 53]
# 20                                    [8, 41, 38, 62]
# 28                                       [35, 28, 39]
# 16                                        [34, 4, 50]
# 8                                            [48, 53]
# 47                                           [35, 31]
# 13                                            [3, 23]
# 22                                           [62, 38]
# 39                                           [35, 31]
# 33                                               [35]
# 34                                               [35]
# 36                                               [35]
# 37                                               [35]
# 35                                               [35]
# 40                                               [15]
# 38                                               [35]
# 31                                               [35]
# 41                                               [20]
# 42                                               [23]
# 43                                               [23]
# 44                                               [23]
# 45                                               [25]
# 46                                               [26]
# 32                                               [35]
# 25                                               [35]
# 30                                               [35]
# 29                                               [35]
# 5                                                 [3]
# 6                                                 [3]
# 7                                                 [3]
# 9                                                [53]
# 10                                               [53]
# 11                                               [53]
# 14                                                [3]
# 15                                               [53]
# 17                                                [4]
# 18                                               [50]
# 21                                                [8]
# 24                                               [35]
# 2                                                [25]
# 26                                               [35]
# 27                                               [41]
# 48                                               [50]

# %%
prop_out
# Out:
#      support                                             graph  \
# 1         33  <gspan_mining.graph.Graph object at 0x1337b65d0>
# 2          3  <gspan_mining.graph.Graph object at 0x1337c3490>
# 3          1  <gspan_mining.graph.Graph object at 0x1337cb690>
# 4          2  <gspan_mining.graph.Graph object at 0x1337d1ad0>
# 5          1  <gspan_mining.graph.Graph object at 0x1337cb590>
# ..       ...                                               ...
# 114        1  <gspan_mining.graph.Graph object at 0x1335869d0>
# 115        1  <gspan_mining.graph.Graph object at 0x133195b10>
# 116        1  <gspan_mining.graph.Graph object at 0x1335f5fd0>
# 117        1  <gspan_mining.graph.Graph object at 0x1337fd650>
# 118        1  <gspan_mining.graph.Graph object at 0x13355bfd0>
#
#                                               graphstr  num_vert  \
# 1                        v 0 X v 1 X e 0 1 enablement          2
# 2    v 0 X v 1 X v 2 X e 0 1 enablement e 1 2 enabl...         3
# 3    v 0 X v 1 X v 2 X v 3 X e 0 1 enablement e 1 2...         4
# 4    v 0 X v 1 X v 2 X e 0 1 enablement e 1 2 manne...         3
# 5    v 0 X v 1 X v 2 X v 3 X e 0 1 enablement e 1 2...         4
# ..                                                 ...       ...
# 114  v 0 X v 1 X v 2 X e 0 1 condition e 1 2 enable...         3
# 115  v 0 X v 1 X v 2 X v 3 X e 0 1 condition e 1 2 ...         4
# 116                          v 0 X v 1 X e 0 1 result          2
# 117                      v 0 X v 1 X e 0 1 comparison          2
# 118  v 0 X v 1 X v 2 X e 0 1 comparison e 1 2 progr...         3
#
#                                        isomorph_graphs
# 1    [0, 9, 12, 16, 20, 24, 27, 28, 45, 46, 56, 57,...
# 2                                        [12, 61, 103]
# 3                                                [103]
# 4                                             [16, 92]
# 5                                                 [92]
# ..                                                 ...
# 114                                               [61]
# 115                                               [61]
# 116                                               [77]
# 117                                              [100]
# 118                                              [100]
#
# [118 rows x 5 columns]

# %%
assert_out
# Out:
#      support                                             graph  \
# 1          4  <gspan_mining.graph.Graph object at 0x133553790>
# 2         28  <gspan_mining.graph.Graph object at 0x133490190>
# 3          5  <gspan_mining.graph.Graph object at 0x133614f50>
# 4          1  <gspan_mining.graph.Graph object at 0x133631b50>
# 5          4  <gspan_mining.graph.Graph object at 0x133633150>
# ..       ...                                               ...
# 108        1  <gspan_mining.graph.Graph object at 0x1338c1290>
# 109        1  <gspan_mining.graph.Graph object at 0x1338b7450>
# 110        1  <gspan_mining.graph.Graph object at 0x13364dbd0>
# 111        1  <gspan_mining.graph.Graph object at 0x133896250>
# 112        1  <gspan_mining.graph.Graph object at 0x1338ae050>
#
#                                               graphstr  num_vert  \
# 1                      v 0 X v 1 X e 0 1 manner-means          2
# 2                     v 0 X v 1 X e 0 1 elab-addition          2
# 3    v 0 X v 1 X v 2 X e 0 1 elab-addition e 1 2 sa...         3
# 4    v 0 X v 1 X v 2 X v 3 X e 0 1 elab-addition e ...         4
# 5    v 0 X v 1 X v 2 X e 0 1 elab-addition e 1 2 jo...         3
# ..                                                 ...       ...
# 108  v 0 X v 1 X v 2 X v 3 X e 0 1 comparison e 1 2...         4
# 109  v 0 X v 1 X v 2 X v 3 X v 4 X e 0 1 comparison...         5
# 110  v 0 X v 1 X v 2 X v 3 X v 4 X v 5 X e 0 1 comp...         6
# 111  v 0 X v 1 X v 2 X v 3 X e 0 1 comparison e 1 2...         4
# 112  v 0 X v 1 X v 2 X v 3 X v 4 X e 0 1 comparison...         5
#
#                                        isomorph_graphs
# 1                                       [0, 41, 69, 5]
# 2    [1, 5, 6, 10, 15, 20, 23, 27, 32, 34, 38, 40, ...
# 3                                  [1, 46, 54, 23, 27]
# 4                                                 [27]
# 5                                      [65, 5, 86, 23]
# ..                                                 ...
# 108                                               [53]
# 109                                               [53]
# 110                                               [53]
# 111                                               [53]
# 112                                               [53]
#
# [112 rows x 5 columns]

# %%
def intersection(lst1, lst2): 
    lst3 = [value for value in lst1 if value in lst2] 
    return lst3

# %%
assert_attr_objs = list(assert_out["isomorph_graphs"])
prop_attr_objs = list(prop_out["isomorph_graphs"])
means_attr_objs = list(means_out["isomorph_graphs"])
result_attr_objs = list(result_out["isomorph_graphs"])
obs_attr_objs = list(obs_out["isomorph_graphs"])
descr_attr_objs = list(descr_out["isomorph_graphs"])

# %%
len(assert_attr_objs)
# Out:
# 112

# %%
prop_objs = objs(prop_out)
assert_objs = objs(assert_out)
result_objs = objs(result_out)
means_objs = objs(means_out)

# %%
print("Prop all objs" + str(len(set(objs(all_args_gspan_out[1])))))
print("\n")
print("Prop all objs : " + str(len(set(prop_objs))))
print("Assert objs : " + str(len(set(assert_objs))))
print("Rslt objs : " + str(len(set(result_objs))))
print("Mean objs : " + str(len(set(means_objs))))
print("\n")
print("Inter(P,A) : "+ str(len(intersection(set(prop_objs), set(assert_objs)))))
print("Inter(P,R) : "+ str(len(intersection(set(prop_objs), set(result_objs)))))
print("Inter(P,M) : "+ str(len(intersection(set(prop_objs), set(means_objs)))))
print("Inter(A,M) : "+ str(len(intersection(set(assert_objs), set(means_objs)))))
print("Inter(A,R) : "+ str(len(intersection(set(assert_objs), set(result_objs)))))
print("Inter(R,M) : "+ str(len(intersection(set(result_objs), set(means_objs)))))
# Out:
# Prop all objs263
#
#
# Prop all objs : 93
# Assert objs : 64
# Rslt objs : 58
# Mean objs : 40
#
#
# Inter(P,A) : 53
# Inter(P,R) : 49
# Inter(P,M) : 37
# Inter(A,M) : 28
# Inter(A,R) : 43
# Inter(R,M) : 33

# %%
prop_out
# Out:
#      support                                             graph  \
# 1         33  <gspan_mining.graph.Graph object at 0x1337b65d0>
# 2          3  <gspan_mining.graph.Graph object at 0x1337c3490>
# 3          1  <gspan_mining.graph.Graph object at 0x1337cb690>
# 4          2  <gspan_mining.graph.Graph object at 0x1337d1ad0>
# 5          1  <gspan_mining.graph.Graph object at 0x1337cb590>
# ..       ...                                               ...
# 114        1  <gspan_mining.graph.Graph object at 0x1335869d0>
# 115        1  <gspan_mining.graph.Graph object at 0x133195b10>
# 116        1  <gspan_mining.graph.Graph object at 0x1335f5fd0>
# 117        1  <gspan_mining.graph.Graph object at 0x1337fd650>
# 118        1  <gspan_mining.graph.Graph object at 0x13355bfd0>
#
#                                               graphstr  num_vert  \
# 1                        v 0 X v 1 X e 0 1 enablement          2
# 2    v 0 X v 1 X v 2 X e 0 1 enablement e 1 2 enabl...         3
# 3    v 0 X v 1 X v 2 X v 3 X e 0 1 enablement e 1 2...         4
# 4    v 0 X v 1 X v 2 X e 0 1 enablement e 1 2 manne...         3
# 5    v 0 X v 1 X v 2 X v 3 X e 0 1 enablement e 1 2...         4
# ..                                                 ...       ...
# 114  v 0 X v 1 X v 2 X e 0 1 condition e 1 2 enable...         3
# 115  v 0 X v 1 X v 2 X v 3 X e 0 1 condition e 1 2 ...         4
# 116                          v 0 X v 1 X e 0 1 result          2
# 117                      v 0 X v 1 X e 0 1 comparison          2
# 118  v 0 X v 1 X v 2 X e 0 1 comparison e 1 2 progr...         3
#
#                                        isomorph_graphs
# 1    [0, 9, 12, 16, 20, 24, 27, 28, 45, 46, 56, 57,...
# 2                                        [12, 61, 103]
# 3                                                [103]
# 4                                             [16, 92]
# 5                                                 [92]
# ..                                                 ...
# 114                                               [61]
# 115                                               [61]
# 116                                               [77]
# 117                                              [100]
# 118                                              [100]
#
# [118 rows x 5 columns]

# %%
assert_out
# Out:
#      support                                             graph  \
# 1          4  <gspan_mining.graph.Graph object at 0x133553790>
# 2         28  <gspan_mining.graph.Graph object at 0x133490190>
# 3          5  <gspan_mining.graph.Graph object at 0x133614f50>
# 4          1  <gspan_mining.graph.Graph object at 0x133631b50>
# 5          4  <gspan_mining.graph.Graph object at 0x133633150>
# ..       ...                                               ...
# 108        1  <gspan_mining.graph.Graph object at 0x1338c1290>
# 109        1  <gspan_mining.graph.Graph object at 0x1338b7450>
# 110        1  <gspan_mining.graph.Graph object at 0x13364dbd0>
# 111        1  <gspan_mining.graph.Graph object at 0x133896250>
# 112        1  <gspan_mining.graph.Graph object at 0x1338ae050>
#
#                                               graphstr  num_vert  \
# 1                      v 0 X v 1 X e 0 1 manner-means          2
# 2                     v 0 X v 1 X e 0 1 elab-addition          2
# 3    v 0 X v 1 X v 2 X e 0 1 elab-addition e 1 2 sa...         3
# 4    v 0 X v 1 X v 2 X v 3 X e 0 1 elab-addition e ...         4
# 5    v 0 X v 1 X v 2 X e 0 1 elab-addition e 1 2 jo...         3
# ..                                                 ...       ...
# 108  v 0 X v 1 X v 2 X v 3 X e 0 1 comparison e 1 2...         4
# 109  v 0 X v 1 X v 2 X v 3 X v 4 X e 0 1 comparison...         5
# 110  v 0 X v 1 X v 2 X v 3 X v 4 X v 5 X e 0 1 comp...         6
# 111  v 0 X v 1 X v 2 X v 3 X e 0 1 comparison e 1 2...         4
# 112  v 0 X v 1 X v 2 X v 3 X v 4 X e 0 1 comparison...         5
#
#                                        isomorph_graphs
# 1                                       [0, 41, 69, 5]
# 2    [1, 5, 6, 10, 15, 20, 23, 27, 32, 34, 38, 40, ...
# 3                                  [1, 46, 54, 23, 27]
# 4                                                 [27]
# 5                                      [65, 5, 86, 23]
# ..                                                 ...
# 108                                               [53]
# 109                                               [53]
# 110                                               [53]
# 111                                               [53]
# 112                                               [53]
#
# [112 rows x 5 columns]

# %%
assert_attr_subs = [gspangraph_to_nxgraph(x) for x in list(assert_out["graph"])]
prop_attr_subs = [gspangraph_to_nxgraph(x) for x in list(prop_out["graph"])]
means_attr_subs = [gspangraph_to_nxgraph(x) for x in list(means_out["graph"])]
result_attr_subs = [gspangraph_to_nxgraph(x) for x in list(result_out["graph"])]
obs_attr_subs = [gspangraph_to_nxgraph(x) for x in list(obs_out["graph"])]
descr_attr_subs = [gspangraph_to_nxgraph(x) for x in list(descr_out["graph"])]

# %%
pmrod = prop_attr_subs+means_attr_subs+result_attr_subs+obs_attr_subs+descr_attr_subs
amrod = assert_attr_subs+means_attr_subs+result_attr_subs+obs_attr_subs+descr_attr_subs
aprod = assert_attr_subs+prop_attr_subs+result_attr_subs+obs_attr_subs+descr_attr_subs
apmrd = assert_attr_subs+prop_attr_subs+means_attr_subs+result_attr_subs+descr_attr_subs
apmro = assert_attr_subs+prop_attr_subs+means_attr_subs+result_attr_subs+obs_attr_subs
apmod = assert_attr_subs+prop_attr_subs+means_attr_subs+obs_attr_subs+obs_attr_subs

# %%
from networkx import weisfeiler_lehman_graph_hash
from collections import Counter

def nxg_counter(gl):
    ghash = [weisfeiler_lehman_graph_hash(x,edge_attr="label") for x in gl]
    hash_dic = {gh:g for gh,g in zip(ghash, gl)}
    return (Counter(ghash), hash_dic)
    
def is_maj(x,y,tsd):
    #boundary = tsd*y/100
    test = x*y/100
    print(test)
    if test >= tsd:
        return True
    else:
        return False
    
def maj_attr(t1, t2, tsd):
    maj = []
    typeocc, type_dic = nxg_counter(t1)
    allocc, all_dic = nxg_counter(t2)
    allg = allocc.values()
    print(typeocc)
    for tk, tcnt in typeocc.items():
        print("TK : " + str(tk))
        #print(tcnt)
        # if they are mapped
        if tk in allocc.keys():
            allg = allocc[tk]
            #print(str(tk))
            #acnt=allocc[tk]
            allcnt=allg+tcnt
            ismaj = is_maj(tcnt, allcnt, tsd)
            if ismaj:
                maj.append(type_dic[k])
    return maj

# %%
def uniques_attr(t1, t2):
    """

    """
    uniques = []
    for gt1 in t1:
        cond = False
        for gt2 in t2:
            if nx.is_isomorphic(gt1, gt2):
                cond = True
                break
        if cond == False:
            uniques.append(gt1)    
        #diff.append(gt1)
    return uniques

# %%
types_subs = [prop_attr_subs,assert_attr_subs,means_attr_subs,result_attr_subs,obs_attr_subs,descr_attr_subs]
types_others = [amrod, pmrod, aprod, apmod, apmrd, apmro]
types_names = ["prop", "assert", "means", "result", "obs", "descr"]

# %%
idx = 0
dbggs = types_subs[idx]
print("Tot Nb Docs : " + str(len(dbggs)))
dbgothergs = types_others[idx]
maj = maj_attr(dbggs, dbgothergs, 60)
# Out:
# Tot Nb Docs : 118
# Counter({'9e9472d976205d470f9797efec75c498': 1, '00c9bdfb9c8a9458c12cc87a3f86cb4f': 1, '85b0c481bdedb2f6a8249d1116e161a7': 1, '42dbbbd4af35356f156df38573a91f54': 1, '1ce0cab5344690971e50406ea4a6003f': 1, '1fb6c11fbc23e39fea60fb3be4096ee6': 1, 'c7b0ea8b9a47b5339170ab306eed3a27': 1, '7710a67ba7469141e5297fce73976191': 1, 'a6255738df5dc0a93b693b4319db6893': 1, '5e7c56d986f2ade284ece1e2d0d19d85': 1, 'fe2c48a3de06377b997d1eb619bf9197': 1, '0bd10404a68a60a5b2e1aac4596e03bc': 1, 'c1f63fcc44494869a17b35048d56242f': 1, '1608e4366c46ad11fa4898076438deae': 1, '6f3f9dc53c92c797e74b1668f5d0df66': 1, 'd4d41627660e5852ffe6006086932f13': 1, '3959ac1b4146e5ded1e6c0b16b963898': 1, '7ab605aeec18fc844d1407e63036b4aa': 1, '569aeedbd16ae14cc4e440bf4396a428': 1, '0d457272f196f8aff1ad6e7486e319cf': 1, '6a2f08bfe46ed8165d297d818af6f8b4': 1, 'ffeba8825e48a9d7e97dc912afbf7c82': 1, 'a321abfa5ce4c33490300bdc0cc8e921': 1, '7aaf651bd1c05385b975e782a1193f80': 1, 'f4956fcdc943fda325b5c785a7025afd': 1, 'af70823453c293a9bbf7b2f5408c9554': 1, '9e9e9108082701493f8583e8c3ce3348': 1, 'f86dbd324fc679b30331ab3d80de5a5d': 1, '2dd590f57f94ba97e32b310b1037b855': 1, '65e534e3a4c28de16fe1816e6907b479': 1, 'ef49d6175b566c90d3f33eda37eb89ee': 1, '388446ac842eda819943826ceb9ef7bf': 1, '9493564625903d10c96f11d7d4338d3d': 1, '09adffa8b37414f7fd76c52fa38dd8a9': 1, '7bcfcf05d3c22b4ea0fdec83889c1d35': 1, 'd7abc67e5bc1da8a9ad0b90c130471a4': 1, 'fbf52fed27a270854141c07dbb3d8ead': 1, '3d3bdbd9159b44d96e2aff4b715de22a': 1, '3fa8c523c0ebb1384edadd691054d6f9': 1, '2c776cacce0556bc13cad8321e03dd63': 1, 'b39cc1fd6ce39a0473d1c2d0ba94d271': 1, '20f85d84601bc0addbdea03f8994725e': 1, 'f505720181ceb6bf214024680aef23ca': 1, '21ce003b285fc4430fa6a351b0229cd5': 1, '6d67ff9607e69d8022ded44ce59696ad': 1, '08a51cbf3630fa9feb29e7de6355af02': 1, '8264d235aaed7bb48effe158c31afa7c': 1, '291e34761af9986556537d516a6b50be': 1, 'f5389a9c14c1fcc7cde891d7c642ca3d': 1, '093dcefd861a12674d31126b4e62a92c': 1, '0c3b038f7206f0ce6149bec4fb32970c': 1, '604e9d310a55b8f2851a2234f41a2e3f': 1, '611b048638f57de2441006a74514bece': 1, 'a53d783b5cda38a0f66afbaf8d5409f0': 1, '3f570bba72d5bda418cdf65ee4bd478d': 1, 'ef0ed53d26fb38f637108e0d43f74905': 1, 'aa3ee22da3e6d2bd7776b4bab51b2c75': 1, '7e38ecd184628d4d9f8b96355b7ac8ab': 1, '200749853fbdb63f8521835e0b25c53e': 1, '9fa6211935cecb296cab47bbdecdfd91': 1, '39af1c8e1a285dbf3f2392af079f3d90': 1, '28604ea17490794fcd8bda89d7e7e7bf': 1, '38e1d0b8fb5c3e859a322f429e43ec89': 1, '9b991ca857f265aa5368711cc41611cc': 1, 'e70d86668e09f5e07f7b37b2aafe8158': 1, '0e62c87f23109bf2d681cd9d63765010': 1, '9495b26446f34a7ebb09c9bdad8e6de4': 1, 'be342e8def9043a4026b0bce79c13281': 1, 'a87649297f5627af4bfe267273eda04a': 1, '5848fbcc6b75a99f37494c1281aa7cfb': 1, '36f9c72415dbbf77ece58d85cc9fbdf6': 1, 'b50ce248180d2bc47e43c1b683cc97ff': 1, 'd037d3311bcb72754462bfaa7909f2a3': 1, '904e1e6699691cfe9f8410402f64ae7e': 1, 'aa8cc5f032e9b4ccb42f1117fad7fad4': 1, '9a197f89c2eb19357735dbdd18265069': 1, '592b05506ed93ab7b2e148d0ccc8a8f8': 1, 'bd48988fe9064dd2a4aa47393248427e': 1, '43da415fa7bf439b55264895b48563a3': 1, '05e879bba8eb430cb34288b72d0753b9': 1, '6ce1863c74da54d810832b991f470402': 1, '740398a00ae8bc927ebf51fc38bc519e': 1, '3c82e739502d8a206ada846c451ae722': 1, 'f3e47a4971c6f6ac4daf46c4d4fb2bff': 1, 'ff5b2b7e87133392a6af33a788167633': 1, '451338ed6200209096e6cf227c9b4024': 1, '3bd68f5266a6e9945e2e68636cb9afe2': 1, '0eb0814491089e3000e2adddcb7ec071': 1, '3ceda8317de504fe7b040474d839b5b7': 1, '2c3c212cc97dbddecd44a4bc0f5dcf5b': 1, '45c3a597ae77ea42e040e9e8f6af0dac': 1, 'c792e453eab69521b2c5fa9bd08672f5': 1, '896b03b42d28dc0a8eaec8e4cee236dd': 1, '507bca72381d51881e2463de074cc98a': 1, 'e01200c8b35a33974613749c78dcdce7': 1, '88d5eec1529897569f749226159f6dba': 1, 'f96ee891e48293c810c3b287383658d6': 1, '769513cd3c8af4b1e1f1c5a3f30bc063': 1, 'dcfd4dbf92dae10daed695da0a79c697': 1, '8e52185e3311cbd83f147a91f0da8731': 1, '98e99b7e29264a5071e26d6efb3a30b9': 1, '9ffef702c6f882783ca809ce96fdf4d0': 1, '515559dce339 ...
# TK : 9e9472d976205d470f9797efec75c498
# 0.04
# TK : 00c9bdfb9c8a9458c12cc87a3f86cb4f
# TK : 85b0c481bdedb2f6a8249d1116e161a7
# TK : 42dbbbd4af35356f156df38573a91f54
# TK : 1ce0cab5344690971e50406ea4a6003f
# TK : 1fb6c11fbc23e39fea60fb3be4096ee6
# TK : c7b0ea8b9a47b5339170ab306eed3a27
# 0.02
# TK : 7710a67ba7469141e5297fce73976191
# 0.04
# TK : a6255738df5dc0a93b693b4319db6893
# 0.04
# TK : 5e7c56d986f2ade284ece1e2d0d19d85
# TK : fe2c48a3de06377b997d1eb619bf9197
# TK : 0bd10404a68a60a5b2e1aac4596e03bc
# TK : c1f63fcc44494869a17b35048d56242f
# TK : 1608e4366c46ad11fa4898076438deae
# TK : 6f3f9dc53c92c797e74b1668f5d0df66
# TK : d4d41627660e5852ffe6006086932f13
# 0.06
# TK : 3959ac1b4146e5ded1e6c0b16b963898
# 0.05
# TK : 7ab605aeec18fc844d1407e63036b4aa
# TK : 569aeedbd16ae14cc4e440bf4396a428
# 0.02
# TK : 0d457272f196f8aff1ad6e7486e319cf
# TK : 6a2f08bfe46ed8165d297d818af6f8b4
# TK : ffeba8825e48a9d7e97dc912afbf7c82
# TK : a321abfa5ce4c33490300bdc0cc8e921
# TK : 7aaf651bd1c05385b975e782a1193f80
# TK : f4956fcdc943fda325b5c785a7025afd
# TK : af70823453c293a9bbf7b2f5408c9554
# TK : 9e9e9108082701493f8583e8c3ce3348
# TK : f86dbd324fc679b30331ab3d80de5a5d
# TK : 2dd590f57f94ba97e32b310b1037b855
# TK : 65e534e3a4c28de16fe1816e6907b479
# TK : ef49d6175b566c90d3f33eda37eb89ee
# TK : 388446ac842eda819943826ceb9ef7bf
# 0.03
# TK : 9493564625903d10c96f11d7d4338d3d
# 0.03
# TK : 09adffa8b37414f7fd76c52fa38dd8a9
# TK : 7bcfcf05d3c22b4ea0fdec83889c1d35
# TK : d7abc67e5bc1da8a9ad0b90c130471a4
# 0.04
# TK : fbf52fed27a270854141c07dbb3d8ead
# TK : 3d3bdbd9159b44d96e2aff4b715de22a
# TK : 3fa8c523c0ebb1384edadd691054d6f9
# 0.03
# TK : 2c776cacce0556bc13cad8321e03dd63
# 0.04
# TK : b39cc1fd6ce39a0473d1c2d0ba94d271
# 0.02
# TK : 20f85d84601bc0addbdea03f8994725e
# TK : f505720181ceb6bf214024680aef23ca
# TK : 21ce003b285fc4430fa6a351b0229cd5
# TK : 6d67ff9607e69d8022ded44ce59696ad
# 0.03
# TK : 08a51cbf3630fa9feb29e7de6355af02
# TK : 8264d235aaed7bb48effe158c31afa7c
# TK : 291e34761af9986556537d516a6b50be
# TK : f5389a9c14c1fcc7cde891d7c642ca3d
# TK : 093dcefd861a12674d31126b4e62a92c
# 0.03
# TK : 0c3b038f7206f0ce6149bec4fb32970c
# TK : 604e9d310a55b8f2851a2234f41a2e3f
# TK : 611b048638f57de2441006a74514bece
# TK : a53d783b5cda38a0f66afbaf8d5409f0
# TK : 3f570bba72d5bda418cdf65ee4bd478d
# TK : ef0ed53d26fb38f637108e0d43f74905
# TK : aa3ee22da3e6d2bd7776b4bab51b2c75
# TK : 7e38ecd184628d4d9f8b96355b7ac8ab
# TK : 200749853fbdb63f8521835e0b25c53e
# TK : 9fa6211935cecb296cab47bbdecdfd91
# TK : 39af1c8e1a285dbf3f2392af079f3d90
# TK : 28604ea17490794fcd8bda89d7e7e7bf
# 0.04
# TK : 38e1d0b8fb5c3e859a322f429e43ec89
# TK : 9b991ca857f265aa5368711cc41611cc
# TK : e70d86668e09f5e07f7b37b2aafe8158
# 0.03
# TK : 0e62c87f23109bf2d681cd9d63765010
# TK : 9495b26446f34a7ebb09c9bdad8e6de4
# TK : be342e8def9043a4026b0bce79c13281
# TK : a87649297f5627af4bfe267273eda04a
# TK : 5848fbcc6b75a99f37494c1281aa7cfb
# TK : 36f9c72415dbbf77ece58d85cc9fbdf6
# 0.02
# TK : b50ce248180d2bc47e43c1b683cc97ff
# TK : d037d3311bcb72754462bfaa7909f2a3
# TK : 904e1e6699691cfe9f8410402f64ae7e
# TK : aa8cc5f032e9b4ccb42f1117fad7fad4
# TK : 9a197f89c2eb19357735dbdd18265069
# TK : 592b05506ed93ab7b2e148d0ccc8a8f8
# TK : bd48988fe9064dd2a4aa47393248427e
# 0.05
# TK : 43da415fa7bf439b55264895b48563a3
# TK : 05e879bba8eb430cb34288b72d0753b9
# 0.02
# TK : 6ce1863c74da54d810832b991f470402
# 0.03
# TK : 740398a00ae8bc927ebf51fc38bc519e
# 0.04
# TK : 3c82e739502d8a206ada846c451ae722
# 0.02
# TK : f3e47a4971c6f6ac4daf46c4d4fb2bff
# TK : ff5b2b7e87133392a6af33a788167633
# TK : 451338ed6200209096e6cf227c9b4024
# TK : 3bd68f5266a6e9945e2e68636cb9afe2
# 0.02
# TK : 0eb0814491089e3000e2adddcb7ec071
# TK : 3ceda8317de504fe7b040474d839b5b7
# TK : 2c3c212cc97dbddecd44a4bc0f5dcf5b
# TK : 45c3a597ae77ea42e040e9e8f6af0dac
# TK : c792e453eab69521b2c5fa9bd08672f5
# TK : 896b03b42d28dc0a8eaec8e4cee236dd
# TK : 507bca72381d51881e2463de074cc98a
# TK : e01200c8b35a33974613749c78dcdce7
# TK : 88d5eec1529897569f749226159f6dba
# TK : f96ee891e48293c810c3b287383658d6
# 0.02
# TK : 769513cd3c8af4b1e1f1c5a3f30bc063
# 0.04
# TK : dcfd4dbf92dae10daed695da0a79c697
# 0.05
# TK : 8e52185e3311cbd83f147a91f0da8731
# TK : 98e99b7e29264a5071e26d6efb3a30b9
# TK : 9ffef702c6f882783ca809ce96fdf4d0
# TK : 515559dce339f98bdf41e59cc2312d58
# 0.05
# TK : c9a079dae18d6cf9f45a7b7304a64036
# 0.02
# TK : 0bab86923e7afe948772aafe6f067213
# 0.04
# TK : ed157621f4c94bd3df5eb552514a18eb
# 0.03
# TK : 752f43defe8ecbc9f2f5777332b33e97
# 0.03
# TK : f0c0cdf15073234933f2b8816ebd974c
# 0.03
# TK : 19cf3d7edb4836c4f2df78c2153b1e3b
# TK : 54f775ff38034adc63b786e51c0f1691
# TK : 2d5ce933aeb825eb2fe3b6c379dd0c1a
# TK : f9acede8c80e50dd3153f506546cfeee
# TK : 9180a23fce98523505bfb691da14aa24
# 0.03
# TK : 63cfea042dc968d0c14a66dbc574492d
# 0.03
# TK : 17d33872756e42a62ad013f405ae5fe4
# TK : a869358102f0d59c82a2e831cd3551c7
# 0.02
# TK : 906eb2c30825bd5140a99b1adc6f1d67
# 0.04
# TK : 7387618d7b70aa01023eab9f5286fe5b

# %%
for subs, others, name in zip(types_subs, types_others, types_names):
    print(name)
    #print(len(uniques_attr(subs, others)))
    for g in maj_attr(subs, others, 10):
        draw_graph(g)
# Out:
# prop
# Counter({'9e9472d976205d470f9797efec75c498': 1, '00c9bdfb9c8a9458c12cc87a3f86cb4f': 1, '85b0c481bdedb2f6a8249d1116e161a7': 1, '42dbbbd4af35356f156df38573a91f54': 1, '1ce0cab5344690971e50406ea4a6003f': 1, '1fb6c11fbc23e39fea60fb3be4096ee6': 1, 'c7b0ea8b9a47b5339170ab306eed3a27': 1, '7710a67ba7469141e5297fce73976191': 1, 'a6255738df5dc0a93b693b4319db6893': 1, '5e7c56d986f2ade284ece1e2d0d19d85': 1, 'fe2c48a3de06377b997d1eb619bf9197': 1, '0bd10404a68a60a5b2e1aac4596e03bc': 1, 'c1f63fcc44494869a17b35048d56242f': 1, '1608e4366c46ad11fa4898076438deae': 1, '6f3f9dc53c92c797e74b1668f5d0df66': 1, 'd4d41627660e5852ffe6006086932f13': 1, '3959ac1b4146e5ded1e6c0b16b963898': 1, '7ab605aeec18fc844d1407e63036b4aa': 1, '569aeedbd16ae14cc4e440bf4396a428': 1, '0d457272f196f8aff1ad6e7486e319cf': 1, '6a2f08bfe46ed8165d297d818af6f8b4': 1, 'ffeba8825e48a9d7e97dc912afbf7c82': 1, 'a321abfa5ce4c33490300bdc0cc8e921': 1, '7aaf651bd1c05385b975e782a1193f80': 1, 'f4956fcdc943fda325b5c785a7025afd': 1, 'af70823453c293a9bbf7b2f5408c9554': 1, '9e9e9108082701493f8583e8c3ce3348': 1, 'f86dbd324fc679b30331ab3d80de5a5d': 1, '2dd590f57f94ba97e32b310b1037b855': 1, '65e534e3a4c28de16fe1816e6907b479': 1, 'ef49d6175b566c90d3f33eda37eb89ee': 1, '388446ac842eda819943826ceb9ef7bf': 1, '9493564625903d10c96f11d7d4338d3d': 1, '09adffa8b37414f7fd76c52fa38dd8a9': 1, '7bcfcf05d3c22b4ea0fdec83889c1d35': 1, 'd7abc67e5bc1da8a9ad0b90c130471a4': 1, 'fbf52fed27a270854141c07dbb3d8ead': 1, '3d3bdbd9159b44d96e2aff4b715de22a': 1, '3fa8c523c0ebb1384edadd691054d6f9': 1, '2c776cacce0556bc13cad8321e03dd63': 1, 'b39cc1fd6ce39a0473d1c2d0ba94d271': 1, '20f85d84601bc0addbdea03f8994725e': 1, 'f505720181ceb6bf214024680aef23ca': 1, '21ce003b285fc4430fa6a351b0229cd5': 1, '6d67ff9607e69d8022ded44ce59696ad': 1, '08a51cbf3630fa9feb29e7de6355af02': 1, '8264d235aaed7bb48effe158c31afa7c': 1, '291e34761af9986556537d516a6b50be': 1, 'f5389a9c14c1fcc7cde891d7c642ca3d': 1, '093dcefd861a12674d31126b4e62a92c': 1, '0c3b038f7206f0ce6149bec4fb32970c': 1, '604e9d310a55b8f2851a2234f41a2e3f': 1, '611b048638f57de2441006a74514bece': 1, 'a53d783b5cda38a0f66afbaf8d5409f0': 1, '3f570bba72d5bda418cdf65ee4bd478d': 1, 'ef0ed53d26fb38f637108e0d43f74905': 1, 'aa3ee22da3e6d2bd7776b4bab51b2c75': 1, '7e38ecd184628d4d9f8b96355b7ac8ab': 1, '200749853fbdb63f8521835e0b25c53e': 1, '9fa6211935cecb296cab47bbdecdfd91': 1, '39af1c8e1a285dbf3f2392af079f3d90': 1, '28604ea17490794fcd8bda89d7e7e7bf': 1, '38e1d0b8fb5c3e859a322f429e43ec89': 1, '9b991ca857f265aa5368711cc41611cc': 1, 'e70d86668e09f5e07f7b37b2aafe8158': 1, '0e62c87f23109bf2d681cd9d63765010': 1, '9495b26446f34a7ebb09c9bdad8e6de4': 1, 'be342e8def9043a4026b0bce79c13281': 1, 'a87649297f5627af4bfe267273eda04a': 1, '5848fbcc6b75a99f37494c1281aa7cfb': 1, '36f9c72415dbbf77ece58d85cc9fbdf6': 1, 'b50ce248180d2bc47e43c1b683cc97ff': 1, 'd037d3311bcb72754462bfaa7909f2a3': 1, '904e1e6699691cfe9f8410402f64ae7e': 1, 'aa8cc5f032e9b4ccb42f1117fad7fad4': 1, '9a197f89c2eb19357735dbdd18265069': 1, '592b05506ed93ab7b2e148d0ccc8a8f8': 1, 'bd48988fe9064dd2a4aa47393248427e': 1, '43da415fa7bf439b55264895b48563a3': 1, '05e879bba8eb430cb34288b72d0753b9': 1, '6ce1863c74da54d810832b991f470402': 1, '740398a00ae8bc927ebf51fc38bc519e': 1, '3c82e739502d8a206ada846c451ae722': 1, 'f3e47a4971c6f6ac4daf46c4d4fb2bff': 1, 'ff5b2b7e87133392a6af33a788167633': 1, '451338ed6200209096e6cf227c9b4024': 1, '3bd68f5266a6e9945e2e68636cb9afe2': 1, '0eb0814491089e3000e2adddcb7ec071': 1, '3ceda8317de504fe7b040474d839b5b7': 1, '2c3c212cc97dbddecd44a4bc0f5dcf5b': 1, '45c3a597ae77ea42e040e9e8f6af0dac': 1, 'c792e453eab69521b2c5fa9bd08672f5': 1, '896b03b42d28dc0a8eaec8e4cee236dd': 1, '507bca72381d51881e2463de074cc98a': 1, 'e01200c8b35a33974613749c78dcdce7': 1, '88d5eec1529897569f749226159f6dba': 1, 'f96ee891e48293c810c3b287383658d6': 1, '769513cd3c8af4b1e1f1c5a3f30bc063': 1, 'dcfd4dbf92dae10daed695da0a79c697': 1, '8e52185e3311cbd83f147a91f0da8731': 1, '98e99b7e29264a5071e26d6efb3a30b9': 1, '9ffef702c6f882783ca809ce96fdf4d0': 1, '515559dce339 ...
# TK : 9e9472d976205d470f9797efec75c498
# 0.04
# TK : 00c9bdfb9c8a9458c12cc87a3f86cb4f
# TK : 85b0c481bdedb2f6a8249d1116e161a7
# TK : 42dbbbd4af35356f156df38573a91f54
# TK : 1ce0cab5344690971e50406ea4a6003f
# TK : 1fb6c11fbc23e39fea60fb3be4096ee6
# TK : c7b0ea8b9a47b5339170ab306eed3a27
# 0.02
# TK : 7710a67ba7469141e5297fce73976191
# 0.04
# TK : a6255738df5dc0a93b693b4319db6893
# 0.04
# TK : 5e7c56d986f2ade284ece1e2d0d19d85
# TK : fe2c48a3de06377b997d1eb619bf9197
# TK : 0bd10404a68a60a5b2e1aac4596e03bc
# TK : c1f63fcc44494869a17b35048d56242f
# TK : 1608e4366c46ad11fa4898076438deae
# TK : 6f3f9dc53c92c797e74b1668f5d0df66
# TK : d4d41627660e5852ffe6006086932f13
# 0.06
# TK : 3959ac1b4146e5ded1e6c0b16b963898
# 0.05
# TK : 7ab605aeec18fc844d1407e63036b4aa
# TK : 569aeedbd16ae14cc4e440bf4396a428
# 0.02
# TK : 0d457272f196f8aff1ad6e7486e319cf
# TK : 6a2f08bfe46ed8165d297d818af6f8b4
# TK : ffeba8825e48a9d7e97dc912afbf7c82
# TK : a321abfa5ce4c33490300bdc0cc8e921
# TK : 7aaf651bd1c05385b975e782a1193f80
# TK : f4956fcdc943fda325b5c785a7025afd
# TK : af70823453c293a9bbf7b2f5408c9554
# TK : 9e9e9108082701493f8583e8c3ce3348
# TK : f86dbd324fc679b30331ab3d80de5a5d
# TK : 2dd590f57f94ba97e32b310b1037b855
# TK : 65e534e3a4c28de16fe1816e6907b479
# TK : ef49d6175b566c90d3f33eda37eb89ee
# TK : 388446ac842eda819943826ceb9ef7bf
# 0.03
# TK : 9493564625903d10c96f11d7d4338d3d
# 0.03
# TK : 09adffa8b37414f7fd76c52fa38dd8a9
# TK : 7bcfcf05d3c22b4ea0fdec83889c1d35
# TK : d7abc67e5bc1da8a9ad0b90c130471a4
# 0.04
# TK : fbf52fed27a270854141c07dbb3d8ead
# TK : 3d3bdbd9159b44d96e2aff4b715de22a
# TK : 3fa8c523c0ebb1384edadd691054d6f9
# 0.03
# TK : 2c776cacce0556bc13cad8321e03dd63
# 0.04
# TK : b39cc1fd6ce39a0473d1c2d0ba94d271
# 0.02
# TK : 20f85d84601bc0addbdea03f8994725e
# TK : f505720181ceb6bf214024680aef23ca
# TK : 21ce003b285fc4430fa6a351b0229cd5
# TK : 6d67ff9607e69d8022ded44ce59696ad
# 0.03
# TK : 08a51cbf3630fa9feb29e7de6355af02
# TK : 8264d235aaed7bb48effe158c31afa7c
# TK : 291e34761af9986556537d516a6b50be
# TK : f5389a9c14c1fcc7cde891d7c642ca3d
# TK : 093dcefd861a12674d31126b4e62a92c
# 0.03
# TK : 0c3b038f7206f0ce6149bec4fb32970c
# TK : 604e9d310a55b8f2851a2234f41a2e3f
# TK : 611b048638f57de2441006a74514bece
# TK : a53d783b5cda38a0f66afbaf8d5409f0
# TK : 3f570bba72d5bda418cdf65ee4bd478d
# TK : ef0ed53d26fb38f637108e0d43f74905
# TK : aa3ee22da3e6d2bd7776b4bab51b2c75
# TK : 7e38ecd184628d4d9f8b96355b7ac8ab
# TK : 200749853fbdb63f8521835e0b25c53e
# TK : 9fa6211935cecb296cab47bbdecdfd91
# TK : 39af1c8e1a285dbf3f2392af079f3d90
# TK : 28604ea17490794fcd8bda89d7e7e7bf
# 0.04
# TK : 38e1d0b8fb5c3e859a322f429e43ec89
# TK : 9b991ca857f265aa5368711cc41611cc
# TK : e70d86668e09f5e07f7b37b2aafe8158
# 0.03
# TK : 0e62c87f23109bf2d681cd9d63765010
# TK : 9495b26446f34a7ebb09c9bdad8e6de4
# TK : be342e8def9043a4026b0bce79c13281
# TK : a87649297f5627af4bfe267273eda04a
# TK : 5848fbcc6b75a99f37494c1281aa7cfb
# TK : 36f9c72415dbbf77ece58d85cc9fbdf6
# 0.02
# TK : b50ce248180d2bc47e43c1b683cc97ff
# TK : d037d3311bcb72754462bfaa7909f2a3
# TK : 904e1e6699691cfe9f8410402f64ae7e
# TK : aa8cc5f032e9b4ccb42f1117fad7fad4
# TK : 9a197f89c2eb19357735dbdd18265069
# TK : 592b05506ed93ab7b2e148d0ccc8a8f8
# TK : bd48988fe9064dd2a4aa47393248427e
# 0.05
# TK : 43da415fa7bf439b55264895b48563a3
# TK : 05e879bba8eb430cb34288b72d0753b9
# 0.02
# TK : 6ce1863c74da54d810832b991f470402
# 0.03
# TK : 740398a00ae8bc927ebf51fc38bc519e
# 0.04
# TK : 3c82e739502d8a206ada846c451ae722
# 0.02
# TK : f3e47a4971c6f6ac4daf46c4d4fb2bff
# TK : ff5b2b7e87133392a6af33a788167633
# TK : 451338ed6200209096e6cf227c9b4024
# TK : 3bd68f5266a6e9945e2e68636cb9afe2
# 0.02
# TK : 0eb0814491089e3000e2adddcb7ec071
# TK : 3ceda8317de504fe7b040474d839b5b7
# TK : 2c3c212cc97dbddecd44a4bc0f5dcf5b
# TK : 45c3a597ae77ea42e040e9e8f6af0dac
# TK : c792e453eab69521b2c5fa9bd08672f5
# TK : 896b03b42d28dc0a8eaec8e4cee236dd
# TK : 507bca72381d51881e2463de074cc98a
# TK : e01200c8b35a33974613749c78dcdce7
# TK : 88d5eec1529897569f749226159f6dba
# TK : f96ee891e48293c810c3b287383658d6
# 0.02
# TK : 769513cd3c8af4b1e1f1c5a3f30bc063
# 0.04
# TK : dcfd4dbf92dae10daed695da0a79c697
# 0.05
# TK : 8e52185e3311cbd83f147a91f0da8731
# TK : 98e99b7e29264a5071e26d6efb3a30b9
# TK : 9ffef702c6f882783ca809ce96fdf4d0
# TK : 515559dce339f98bdf41e59cc2312d58
# 0.05
# TK : c9a079dae18d6cf9f45a7b7304a64036
# 0.02
# TK : 0bab86923e7afe948772aafe6f067213
# 0.04
# TK : ed157621f4c94bd3df5eb552514a18eb
# 0.03
# TK : 752f43defe8ecbc9f2f5777332b33e97
# 0.03
# TK : f0c0cdf15073234933f2b8816ebd974c
# 0.03
# TK : 19cf3d7edb4836c4f2df78c2153b1e3b
# TK : 54f775ff38034adc63b786e51c0f1691
# TK : 2d5ce933aeb825eb2fe3b6c379dd0c1a
# TK : f9acede8c80e50dd3153f506546cfeee
# TK : 9180a23fce98523505bfb691da14aa24
# 0.03
# TK : 63cfea042dc968d0c14a66dbc574492d
# 0.03
# TK : 17d33872756e42a62ad013f405ae5fe4
# TK : a869358102f0d59c82a2e831cd3551c7
# 0.02
# TK : 906eb2c30825bd5140a99b1adc6f1d67
# 0.04
# TK : 7387618d7b70aa01023eab9f5286fe5b
# assert
# Counter({'bd48988fe9064dd2a4aa47393248427e': 1, 'd4d41627660e5852ffe6006086932f13': 1, '70f9a284ab92b4690245d88dd54ae9d9': 1, 'e3656d1e40cc16da86de9684ca07c135': 1, '2c776cacce0556bc13cad8321e03dd63': 1, 'e226e57ecc69108581914f4183343062': 1, 'a7e78f36554f36e586b61b8b97a01b02': 1, 'a37d3ad3987c8c917640e852a8eaa0b7': 1, 'cc41efb81f7726a9df7f506d65b6b8f7': 1, '71454e7d4d81c74ab207e23575e47a3c': 1, '6d67ff9607e69d8022ded44ce59696ad': 1, '46141892f55f15d58d9862e328973e12': 1, '59d63f51f294d9b41940985e298cfa0a': 1, '31b686e276f7459cdd77fe43572d0312': 1, 'e77280c94ac0f26a12ff001740adea1a': 1, '388446ac842eda819943826ceb9ef7bf': 1, '523c1a88b8a60e8ec33802de8e2da8aa': 1, '4b4a1794d3aa774cddaa513306860e39': 1, 'e4e55e5e185e4bcc83787c1d16e27e78': 1, 'b6e4f6a0672ad73c23d9fcfdb8769e19': 1, '5eba4dbc6de5507755e69bdc840289a3': 1, '830086fea1dce8646923a2b315452245': 1, '2028d3fea4e7ac89ec6281acd9aff454': 1, 'af7d6312708c6b3dd1aa66594d3b92ee': 1, '824d008bf150fcf7158fc0794e2fdc25': 1, 'd52eb56ca6e4671eccf31569e0ec7922': 1, 'a613d6bbd157e93454f8b7a5e8d5d04f': 1, 'e1877fdae18136a71a9c6ea9cb5f1271': 1, 'c60459dcd16800ee72fdc03771f2bc08': 1, '3959ac1b4146e5ded1e6c0b16b963898': 1, '1dac16678a8f954e8a7014d02e785db2': 1, '95b973abf26c26e8450b5165f326f0da': 1, '6104ec939d1e447eee7ba45aabb558c2': 1, '9493564625903d10c96f11d7d4338d3d': 1, 'd7abc67e5bc1da8a9ad0b90c130471a4': 1, 'c0f50ce7c617db24e353e76d14ab4f32': 1, '72ad5ff1c7a22303efd98b3d4ad517fa': 1, '3fa8c523c0ebb1384edadd691054d6f9': 1, '769513cd3c8af4b1e1f1c5a3f30bc063': 1, '9180a23fce98523505bfb691da14aa24': 1, '63cfea042dc968d0c14a66dbc574492d': 1, 'e28a0fe70718a7a7152d352943ed23cd': 1, 'd47e6652168cbc15d09f6001641db51b': 1, '8ee228f1c42110249fda92e1a5c88e81': 1, '51b670191c97a06b60f68d4742fd4b8a': 1, '917e921cee8a9df3e1b7cdf0a3c0b505': 1, '1adc4cff8f729503413e79fcc7a852a1': 1, '60f633929e4569fd1a9b04399b9a248f': 1, 'cca14457155ec0b4a2956f96300b8d88': 1, '2f0c4660e47643cffb6d54a961b955c5': 1, 'd55d835a775bbf438a0336801759456d': 1, '9309eb0cae1f0e5b825b4695370b7a52': 1, '17118f815767ec3192bc761729fb3d59': 1, '5cbecf415279f242f66ffb6af333a333': 1, '9b8bf073398c962e2566d450aa92fc8c': 1, '4a5b88a62cfa3a6ef5b43523269ca890': 1, '9e9472d976205d470f9797efec75c498': 1, 'c7b0ea8b9a47b5339170ab306eed3a27': 1, '380ddf4fe6200f6543bfbaf65bbe898d': 1, '28604ea17490794fcd8bda89d7e7e7bf': 1, 'e70d86668e09f5e07f7b37b2aafe8158': 1, '5827c670fb825a85ed43d171e7d77328': 1, 'aa5fd245047b6d8dd1177aee271b5a3d': 1, 'b108bd26e930a70503ec6cb00452d9ce': 1, '39616d1919d32087b399e3dc99969554': 1, '9ca7733cd3d49f6c5d98ed2f0b21b6a8': 1, '36f9c72415dbbf77ece58d85cc9fbdf6': 1, 'ea7b2e3690ef45b88b0b36052a854b55': 1, '5b2bc49a6de60e91767728dd5afc32d1': 1, 'dcfd4dbf92dae10daed695da0a79c697': 1, 'a84575ab4dfc5d9a7d83dfefdefc7b24': 1, '039909d3779ebe6c66ddd7a1f7b57f39': 1, '515559dce339f98bdf41e59cc2312d58': 1, 'b88624ea4dc73ac7500345c6a4a88d00': 1, 'f3267f9ce5c97192cd9c6609b23ef8c7': 1, '477fa9d18af840152207c83bcd18eb00': 1, 'e76fea460f40ba713c733a1fe66c98c1': 1, 'a185fa3d8e720a391a9ff8abf586ed36': 1, '3f06df2731ee793ed8ea8e77457eaafb': 1, '94920c3201cbf67eb7b1a49f7ad23fab': 1, '45f1ca15044ac42f95403d77e1e8979f': 1, 'c250d42a2bb682aa85ff5745ca84fada': 1, 'cba83cb398c3be8e6649ff777823b71a': 1, '6ce1863c74da54d810832b991f470402': 1, '7710a67ba7469141e5297fce73976191': 1, '0bab86923e7afe948772aafe6f067213': 1, 'f0c0cdf15073234933f2b8816ebd974c': 1, '9e1e72fef63c544b56d0905bfea97c3e': 1, '910b0a3d167c61c75de2ef96cd6de96b': 1, 'fd0bd2e4446bd07d6d733f6583a6bf3d': 1, 'df4f494405db2ecdb307d6c061f4cc7b': 1, 'b4afb54d2e3008c21fc3375f96ad5c22': 1, '752f43defe8ecbc9f2f5777332b33e97': 1, 'b4df4b9a162c0084f465eed0fb644aa3': 1, '788ac73ae900e3c72f2eb94c59890941': 1, 'f461e87bb69d5e91c0b17687c8372d28': 1, '0dcf75deb415a8dda39ffb4ba6e7e669': 1, '7b0efd681eebe695386896145ae0f1b7': 1, 'ed157621f4c94bd3df5eb552514a18eb': 1, '22fd195cd87dd364ba4115149ffafb18': 1, '740398a00ae8bc927ebf51fc38bc519e': 1, 'ea83b4521a09da6ad9839c0cf1ae249a': 1, '32acc3021c40 ...
# TK : bd48988fe9064dd2a4aa47393248427e
# 0.05
# TK : d4d41627660e5852ffe6006086932f13
# 0.06
# TK : 70f9a284ab92b4690245d88dd54ae9d9
# 0.03
# TK : e3656d1e40cc16da86de9684ca07c135
# 0.02
# TK : 2c776cacce0556bc13cad8321e03dd63
# 0.04
# TK : e226e57ecc69108581914f4183343062
# TK : a7e78f36554f36e586b61b8b97a01b02
# TK : a37d3ad3987c8c917640e852a8eaa0b7
# TK : cc41efb81f7726a9df7f506d65b6b8f7
# TK : 71454e7d4d81c74ab207e23575e47a3c
# 0.03
# TK : 6d67ff9607e69d8022ded44ce59696ad
# 0.03
# TK : 46141892f55f15d58d9862e328973e12
# TK : 59d63f51f294d9b41940985e298cfa0a
# TK : 31b686e276f7459cdd77fe43572d0312
# TK : e77280c94ac0f26a12ff001740adea1a
# TK : 388446ac842eda819943826ceb9ef7bf
# 0.03
# TK : 523c1a88b8a60e8ec33802de8e2da8aa
# TK : 4b4a1794d3aa774cddaa513306860e39
# TK : e4e55e5e185e4bcc83787c1d16e27e78
# TK : b6e4f6a0672ad73c23d9fcfdb8769e19
# TK : 5eba4dbc6de5507755e69bdc840289a3
# TK : 830086fea1dce8646923a2b315452245
# TK : 2028d3fea4e7ac89ec6281acd9aff454
# TK : af7d6312708c6b3dd1aa66594d3b92ee
# TK : 824d008bf150fcf7158fc0794e2fdc25
# TK : d52eb56ca6e4671eccf31569e0ec7922
# TK : a613d6bbd157e93454f8b7a5e8d5d04f
# TK : e1877fdae18136a71a9c6ea9cb5f1271
# TK : c60459dcd16800ee72fdc03771f2bc08
# TK : 3959ac1b4146e5ded1e6c0b16b963898
# 0.05
# TK : 1dac16678a8f954e8a7014d02e785db2
# 0.02
# TK : 95b973abf26c26e8450b5165f326f0da
# 0.02
# TK : 6104ec939d1e447eee7ba45aabb558c2
# 0.02
# TK : 9493564625903d10c96f11d7d4338d3d
# 0.03
# TK : d7abc67e5bc1da8a9ad0b90c130471a4
# 0.04
# TK : c0f50ce7c617db24e353e76d14ab4f32
# 0.02
# TK : 72ad5ff1c7a22303efd98b3d4ad517fa
# TK : 3fa8c523c0ebb1384edadd691054d6f9
# 0.03
# TK : 769513cd3c8af4b1e1f1c5a3f30bc063
# 0.04
# TK : 9180a23fce98523505bfb691da14aa24
# 0.03
# TK : 63cfea042dc968d0c14a66dbc574492d
# 0.03
# TK : e28a0fe70718a7a7152d352943ed23cd
# 0.02
# TK : d47e6652168cbc15d09f6001641db51b
# TK : 8ee228f1c42110249fda92e1a5c88e81
# TK : 51b670191c97a06b60f68d4742fd4b8a
# TK : 917e921cee8a9df3e1b7cdf0a3c0b505
# TK : 1adc4cff8f729503413e79fcc7a852a1
# TK : 60f633929e4569fd1a9b04399b9a248f
# TK : cca14457155ec0b4a2956f96300b8d88
# TK : 2f0c4660e47643cffb6d54a961b955c5
# TK : d55d835a775bbf438a0336801759456d
# TK : 9309eb0cae1f0e5b825b4695370b7a52
# TK : 17118f815767ec3192bc761729fb3d59
# TK : 5cbecf415279f242f66ffb6af333a333
# TK : 9b8bf073398c962e2566d450aa92fc8c
# TK : 4a5b88a62cfa3a6ef5b43523269ca890
# TK : 9e9472d976205d470f9797efec75c498
# 0.04
# TK : c7b0ea8b9a47b5339170ab306eed3a27
# 0.02
# TK : 380ddf4fe6200f6543bfbaf65bbe898d
# 0.03
# TK : 28604ea17490794fcd8bda89d7e7e7bf
# 0.04
# TK : e70d86668e09f5e07f7b37b2aafe8158
# 0.03
# TK : 5827c670fb825a85ed43d171e7d77328
# 0.02
# TK : aa5fd245047b6d8dd1177aee271b5a3d
# TK : b108bd26e930a70503ec6cb00452d9ce
# TK : 39616d1919d32087b399e3dc99969554
# TK : 9ca7733cd3d49f6c5d98ed2f0b21b6a8
# 0.02
# TK : 36f9c72415dbbf77ece58d85cc9fbdf6
# 0.02
# TK : ea7b2e3690ef45b88b0b36052a854b55
# TK : 5b2bc49a6de60e91767728dd5afc32d1
# TK : dcfd4dbf92dae10daed695da0a79c697
# 0.05
# TK : a84575ab4dfc5d9a7d83dfefdefc7b24
# TK : 039909d3779ebe6c66ddd7a1f7b57f39
# TK : 515559dce339f98bdf41e59cc2312d58
# 0.05
# TK : b88624ea4dc73ac7500345c6a4a88d00
# 0.02
# TK : f3267f9ce5c97192cd9c6609b23ef8c7
# 0.02
# TK : 477fa9d18af840152207c83bcd18eb00
# TK : e76fea460f40ba713c733a1fe66c98c1
# TK : a185fa3d8e720a391a9ff8abf586ed36
# 0.02
# TK : 3f06df2731ee793ed8ea8e77457eaafb
# TK : 94920c3201cbf67eb7b1a49f7ad23fab
# TK : 45f1ca15044ac42f95403d77e1e8979f
# TK : c250d42a2bb682aa85ff5745ca84fada
# TK : cba83cb398c3be8e6649ff777823b71a
# TK : 6ce1863c74da54d810832b991f470402
# 0.03
# TK : 7710a67ba7469141e5297fce73976191
# 0.04
# TK : 0bab86923e7afe948772aafe6f067213
# 0.04
# TK : f0c0cdf15073234933f2b8816ebd974c
# 0.03
# TK : 9e1e72fef63c544b56d0905bfea97c3e
# TK : 910b0a3d167c61c75de2ef96cd6de96b
# TK : fd0bd2e4446bd07d6d733f6583a6bf3d
# TK : df4f494405db2ecdb307d6c061f4cc7b
# TK : b4afb54d2e3008c21fc3375f96ad5c22
# 0.02
# TK : 752f43defe8ecbc9f2f5777332b33e97
# 0.03
# TK : b4df4b9a162c0084f465eed0fb644aa3
# TK : 788ac73ae900e3c72f2eb94c59890941
# TK : f461e87bb69d5e91c0b17687c8372d28
# TK : 0dcf75deb415a8dda39ffb4ba6e7e669
# 0.02
# TK : 7b0efd681eebe695386896145ae0f1b7
# 0.03
# TK : ed157621f4c94bd3df5eb552514a18eb
# 0.03
# TK : 22fd195cd87dd364ba4115149ffafb18
# TK : 740398a00ae8bc927ebf51fc38bc519e
# 0.04
# TK : ea83b4521a09da6ad9839c0cf1ae249a
# 0.03
# TK : 32acc3021c403ec36c35ff969961334b
# 0.02
# TK : a869358102f0d59c82a2e831cd3551c7
# 0.02
# TK : 906eb2c30825bd5140a99b1adc6f1d67
# 0.04
# TK : 95d8a3db94da9a69d055b17f3250e16c
# TK : 815b1c6810e3203e2f5b6d1ca91bd84a
# 0.02
# TK : 6ec7f7f4fa737012acb736a151c5bd0a
# TK : ccc9e13ed2640a52b6f58bd73ca891a4
# TK : 1f18370d947f6adf4d1a948a44f82645
# TK : 513cc524e4bdfd89d9c8b15db7ca850c
# TK : 43caaaac77edd060c4be05018a87d7a2
# means
# Counter({'bd48988fe9064dd2a4aa47393248427e': 1, '05e879bba8eb430cb34288b72d0753b9': 1, '9e9472d976205d470f9797efec75c498': 1, '380ddf4fe6200f6543bfbaf65bbe898d': 1, '196efca38a999dcc7d435980bea9bca6': 1, '3758565ac68c5ee3c7c5017ee0331220': 1, '1a33266ec0528f7e7b68d1753e9d2f15': 1, 'fe7c0a32a40566e04056adc54641f84b': 1, 'b6f8395921b7490e959f3471653d5da4': 1, 'e6eb4379389c906cf9cbe0646245ae1f': 1, 'aba2be0410affd66c2d7e124778cd1ac': 1, '515559dce339f98bdf41e59cc2312d58': 1, 'b88624ea4dc73ac7500345c6a4a88d00': 1, 'caf0a7eefee3204625d7f0caba93b723': 1, 'f3267f9ce5c97192cd9c6609b23ef8c7': 1, '740398a00ae8bc927ebf51fc38bc519e': 1, '3bd68f5266a6e9945e2e68636cb9afe2': 1, '5dceb59c2322f3b1b87bd82a65fa3443': 1, 'd4d41627660e5852ffe6006086932f13': 1, '2c776cacce0556bc13cad8321e03dd63': 1, '71454e7d4d81c74ab207e23575e47a3c': 1, 'b39cc1fd6ce39a0473d1c2d0ba94d271': 1, 'd7abc67e5bc1da8a9ad0b90c130471a4': 1, 'c0f50ce7c617db24e353e76d14ab4f32': 1, '0bb32a3418d0eb93aeb73482e8d44c0f': 1, '7e2170ddfa621674d8979aa1bf3c1d80': 1, 'c37ff14955e7b20cf3d061df4be1a901': 1, '3959ac1b4146e5ded1e6c0b16b963898': 1, '1dac16678a8f954e8a7014d02e785db2': 1, '95b973abf26c26e8450b5165f326f0da': 1, '3eca80a229918cab7cd1becc13582754': 1, 'd1f8d8184e44e7b83d65ace362e0724d': 1, '569aeedbd16ae14cc4e440bf4396a428': 1, 'e2d42d1fe5ab999730427dd2ce7c86fe': 1, 'b43fa452b2b5d342775eadba8054a792': 1, 'a42dc280631764bcac8b2185cc4b64c6': 1, '718d2c16af3e059946cd33f322c56792': 1, 'c1544b45912fea3ba5cf5286a26046f0': 1, '70f9a284ab92b4690245d88dd54ae9d9': 1, 'a6255738df5dc0a93b693b4319db6893': 1, 'ea83b4521a09da6ad9839c0cf1ae249a': 1, '0bab86923e7afe948772aafe6f067213': 1, '7b0efd681eebe695386896145ae0f1b7': 1, 'bf7e506b4d88e724fc8c35a883c0363d': 1, '7710a67ba7469141e5297fce73976191': 1, 'dcfd4dbf92dae10daed695da0a79c697': 1, '769513cd3c8af4b1e1f1c5a3f30bc063': 1, '28604ea17490794fcd8bda89d7e7e7bf': 1})
# TK : bd48988fe9064dd2a4aa47393248427e
# 0.05
# TK : 05e879bba8eb430cb34288b72d0753b9
# 0.02
# TK : 9e9472d976205d470f9797efec75c498
# 0.04
# TK : 380ddf4fe6200f6543bfbaf65bbe898d
# 0.03
# TK : 196efca38a999dcc7d435980bea9bca6
# TK : 3758565ac68c5ee3c7c5017ee0331220
# TK : 1a33266ec0528f7e7b68d1753e9d2f15
# TK : fe7c0a32a40566e04056adc54641f84b
# TK : b6f8395921b7490e959f3471653d5da4
# TK : e6eb4379389c906cf9cbe0646245ae1f
# TK : aba2be0410affd66c2d7e124778cd1ac
# TK : 515559dce339f98bdf41e59cc2312d58
# 0.05
# TK : b88624ea4dc73ac7500345c6a4a88d00
# 0.02
# TK : caf0a7eefee3204625d7f0caba93b723
# TK : f3267f9ce5c97192cd9c6609b23ef8c7
# 0.02
# TK : 740398a00ae8bc927ebf51fc38bc519e
# 0.04
# TK : 3bd68f5266a6e9945e2e68636cb9afe2
# 0.02
# TK : 5dceb59c2322f3b1b87bd82a65fa3443
# TK : d4d41627660e5852ffe6006086932f13
# 0.06
# TK : 2c776cacce0556bc13cad8321e03dd63
# 0.04
# TK : 71454e7d4d81c74ab207e23575e47a3c
# 0.03
# TK : b39cc1fd6ce39a0473d1c2d0ba94d271
# 0.02
# TK : d7abc67e5bc1da8a9ad0b90c130471a4
# 0.04
# TK : c0f50ce7c617db24e353e76d14ab4f32
# 0.02
# TK : 0bb32a3418d0eb93aeb73482e8d44c0f
# TK : 7e2170ddfa621674d8979aa1bf3c1d80
# TK : c37ff14955e7b20cf3d061df4be1a901
# TK : 3959ac1b4146e5ded1e6c0b16b963898
# 0.05
# TK : 1dac16678a8f954e8a7014d02e785db2
# 0.02
# TK : 95b973abf26c26e8450b5165f326f0da
# 0.02
# TK : 3eca80a229918cab7cd1becc13582754
# TK : d1f8d8184e44e7b83d65ace362e0724d
# TK : 569aeedbd16ae14cc4e440bf4396a428
# 0.02
# TK : e2d42d1fe5ab999730427dd2ce7c86fe
# TK : b43fa452b2b5d342775eadba8054a792
# TK : a42dc280631764bcac8b2185cc4b64c6
# TK : 718d2c16af3e059946cd33f322c56792
# TK : c1544b45912fea3ba5cf5286a26046f0
# TK : 70f9a284ab92b4690245d88dd54ae9d9
# 0.03
# TK : a6255738df5dc0a93b693b4319db6893
# 0.04
# TK : ea83b4521a09da6ad9839c0cf1ae249a
# 0.03
# TK : 0bab86923e7afe948772aafe6f067213
# 0.04
# TK : 7b0efd681eebe695386896145ae0f1b7
# 0.03
# TK : bf7e506b4d88e724fc8c35a883c0363d
# TK : 7710a67ba7469141e5297fce73976191
# 0.04
# TK : dcfd4dbf92dae10daed695da0a79c697
# 0.05
# TK : 769513cd3c8af4b1e1f1c5a3f30bc063
# 0.04
# TK : 28604ea17490794fcd8bda89d7e7e7bf
# 0.04
# result
# Counter({'0bab86923e7afe948772aafe6f067213': 1, '5d477ea53422dec1a6c60e474c8e3701': 1, '882f25df926c11908eb012e754107229': 1, '429b1e94c33cb5f1e7c163573f9a198d': 1, 'f6d663f090b9719ff9d84e822f60ac06': 1, '752f43defe8ecbc9f2f5777332b33e97': 1, '1567d2da64b25ad6cc0f4dc03c294b27': 1, '84add6db49d5ff33abb1b0bacefad9bf': 1, '9ff2a2326d5714f94df979bc2a0057cc': 1, '50d42e818ef20a492019812bc59f5f29': 1, 'd7ffdbe75583a9d4782bdb8ae6301a2a': 1, 'e2f08390999eb93c2f30f39a0185fdd9': 1, 'db97563790f9d5625823cb32acc43782': 1, 'c5fbaafa44834ed83b08d7fa9482673e': 1, 'cb2ec1acad9f00a0771edc5d4b4377d6': 1, 'd5d800028634aabe75464343478b9c75': 1, 'b9dbd34b58098299e2d70550b3c53dd2': 1, '6dc83e48d77247337423e7df441f5ab4': 1, 'b1d1f4f69e6481ceadd510afe39f18d4': 1, '01e50c3f9a9d6856e3b8691ca0e947f4': 1, 'e50ed76fb270a51fc2b5e3a262d0a2f5': 1, 'bd0b3c3509b67e9baf0f63a41e095087': 1, '0dcf75deb415a8dda39ffb4ba6e7e669': 1, 'fcba39bf425917390c10c7c596368b63': 1, '93703ac45fd032d0ea86552b281e6195': 1, '888434271c194629eca9624140ada1fb': 1, '611f7dc0d2879ffaeeaee863f3826722': 1, 'cba73745743cdf4bad9005321eef2a13': 1, '4dbbeda9b6af4b4b5075ecd7fb9ece45': 1, 'e0992558ed974a16497a7e0feb34f373': 1, 'a0a0ed0a12e7b950d70de5a8a623b87e': 1, 'f844c1a8114d90c992d0c64e5f9ec0e8': 1, '5af49b6ab902e88f70fce87846e4fabc': 1, 'be5bcea745dfd9c32b9f2e3cccc5b498': 1, 'b4afb54d2e3008c21fc3375f96ad5c22': 1, 'b9342bb050488c9f17886ea361997058': 1, '301a70e7f847404f65c25ccc7732b5f4': 1, 'b66e7261ec1ab3a5715dc44315056f33': 1, '931c77b64d50408c495634a7e90374b7': 1, 'a147068e592ab9498e53f3c5c15a1e04': 1, 'e13e8b0ff464bd58dc4c7212877a9739': 1, 'dd62bf57e184217c8eea53b29018b3d2': 1, '7b0efd681eebe695386896145ae0f1b7': 1, '07cabdccafc4dcbe4ea2526dcb9fd1f5': 1, '15aad338972f0a5207c6fa01004a265c': 1, 'd377547a92a1e8b2fe3b5b8654c27acb': 1, '2b4ae9c6de1d916c5c492ea0a7ca0e92': 1, '512851e27c7f917e0dff8d8be452941a': 1, 'ed157621f4c94bd3df5eb552514a18eb': 1, '544b10d157bc084f8196774febc2f033': 1, 'f0c0cdf15073234933f2b8816ebd974c': 1, '1e307e311ce161fa2d8340a338b38d27': 1, '495113ead51fc5ea96a251e7f976b47b': 1, '134d54152ba01e9fe88f1a0a5b1ad6be': 1, '3700547c42da7ae09c24ec6b6aa00a32': 1, '515559dce339f98bdf41e59cc2312d58': 1, 'c9a079dae18d6cf9f45a7b7304a64036': 1, 'b51b7c96582c8ced37ab84152d8ecd7f': 1, 'a185fa3d8e720a391a9ff8abf586ed36': 1, 'a9bbb8c3eb81c1a9f3fbc7898cc594f1': 1, '3a238c7eab4d6aa07a2d131c7a16b923': 1, 'bbe3a7af514a1e93b555a93e1b563527': 1, '6ce1863c74da54d810832b991f470402': 1, 'd4d41627660e5852ffe6006086932f13': 1, '388446ac842eda819943826ceb9ef7bf': 1, '2c776cacce0556bc13cad8321e03dd63': 1, '209191583ccd864db4369c4e9795ac0f': 1, '69fac9d833a4c83e16118a0f39cc3cff': 1, '65f1123aec394810d4c120487c8c317f': 1, '71454e7d4d81c74ab207e23575e47a3c': 1, 'b36a1f37f42016168752c5f00ef2a7bb': 1, '33e61180cbe419148bd8607fdfd71ab0': 1, 'd9bcb7184304e0c036f3c0b819aea987': 1, '71ce7a01c6102f829ee84aaa7053d8a7': 1, '019549c90fb14deef750ea44726c50ee': 1, '33de07934db7fd50281e3d07f6926a5d': 1, 'f52b30ff99fde36cdbb696e2d4c08157': 1, '3cddf41bb674e21ec63e5eb6e6e63073': 1, '70f9a284ab92b4690245d88dd54ae9d9': 1, 'e3656d1e40cc16da86de9684ca07c135': 1, '12c44dfd4e16f6ee5cd99a4a046cd19e': 1, '3d96be65d05d8a490198a0d78106ff69': 1, '7340ddb3e24efb80cab692b769a7d5bf': 1, 'aa50ec24a88252eb3408208b80d9cb28': 1, 'c0f9f87e90a90a5d9e1fc2d72865a15c': 1, '55d549fdc26434ace4714597d05b0b28': 1, '9493564625903d10c96f11d7d4338d3d': 1, '3959ac1b4146e5ded1e6c0b16b963898': 1, '6104ec939d1e447eee7ba45aabb558c2': 1, '10918c8f992ba8c9f6589510926be915': 1, '3fa8c523c0ebb1384edadd691054d6f9': 1, 'd7abc67e5bc1da8a9ad0b90c130471a4': 1, '093dcefd861a12674d31126b4e62a92c': 1, '769513cd3c8af4b1e1f1c5a3f30bc063': 1, 'ea83b4521a09da6ad9839c0cf1ae249a': 1, 'f78973a4c91c7c69489dc6d632138ec4': 1, '7619aa25dae9bc7a483e6614db291f20': 1, '32acc3021c403ec36c35ff969961334b': 1, '9e9472d976205d470f9797efec75c498': 1, 'bdeec84d4af809377a9fbbea4680e9ac': 1, 'b289ec1a263fa1d1cc159d0907650910': 1, '6a3e8675fbbe2e6dc11a3ad3287ba67a': 1, '0bb86bb7bb44 ...
# TK : 0bab86923e7afe948772aafe6f067213
# 0.04
# TK : 5d477ea53422dec1a6c60e474c8e3701
# TK : 882f25df926c11908eb012e754107229
# TK : 429b1e94c33cb5f1e7c163573f9a198d
# TK : f6d663f090b9719ff9d84e822f60ac06
# TK : 752f43defe8ecbc9f2f5777332b33e97
# 0.03
# TK : 1567d2da64b25ad6cc0f4dc03c294b27
# TK : 84add6db49d5ff33abb1b0bacefad9bf
# TK : 9ff2a2326d5714f94df979bc2a0057cc
# TK : 50d42e818ef20a492019812bc59f5f29
# TK : d7ffdbe75583a9d4782bdb8ae6301a2a
# TK : e2f08390999eb93c2f30f39a0185fdd9
# TK : db97563790f9d5625823cb32acc43782
# TK : c5fbaafa44834ed83b08d7fa9482673e
# TK : cb2ec1acad9f00a0771edc5d4b4377d6
# TK : d5d800028634aabe75464343478b9c75
# TK : b9dbd34b58098299e2d70550b3c53dd2
# TK : 6dc83e48d77247337423e7df441f5ab4
# TK : b1d1f4f69e6481ceadd510afe39f18d4
# TK : 01e50c3f9a9d6856e3b8691ca0e947f4
# TK : e50ed76fb270a51fc2b5e3a262d0a2f5
# TK : bd0b3c3509b67e9baf0f63a41e095087
# TK : 0dcf75deb415a8dda39ffb4ba6e7e669
# 0.02
# TK : fcba39bf425917390c10c7c596368b63
# TK : 93703ac45fd032d0ea86552b281e6195
# TK : 888434271c194629eca9624140ada1fb
# TK : 611f7dc0d2879ffaeeaee863f3826722
# TK : cba73745743cdf4bad9005321eef2a13
# TK : 4dbbeda9b6af4b4b5075ecd7fb9ece45
# TK : e0992558ed974a16497a7e0feb34f373
# TK : a0a0ed0a12e7b950d70de5a8a623b87e
# TK : f844c1a8114d90c992d0c64e5f9ec0e8
# TK : 5af49b6ab902e88f70fce87846e4fabc
# TK : be5bcea745dfd9c32b9f2e3cccc5b498
# TK : b4afb54d2e3008c21fc3375f96ad5c22
# 0.02
# TK : b9342bb050488c9f17886ea361997058
# TK : 301a70e7f847404f65c25ccc7732b5f4
# TK : b66e7261ec1ab3a5715dc44315056f33
# TK : 931c77b64d50408c495634a7e90374b7
# TK : a147068e592ab9498e53f3c5c15a1e04
# TK : e13e8b0ff464bd58dc4c7212877a9739
# TK : dd62bf57e184217c8eea53b29018b3d2
# TK : 7b0efd681eebe695386896145ae0f1b7
# 0.03
# TK : 07cabdccafc4dcbe4ea2526dcb9fd1f5
# TK : 15aad338972f0a5207c6fa01004a265c
# TK : d377547a92a1e8b2fe3b5b8654c27acb
# TK : 2b4ae9c6de1d916c5c492ea0a7ca0e92
# TK : 512851e27c7f917e0dff8d8be452941a
# TK : ed157621f4c94bd3df5eb552514a18eb
# 0.03
# TK : 544b10d157bc084f8196774febc2f033
# TK : f0c0cdf15073234933f2b8816ebd974c
# 0.03
# TK : 1e307e311ce161fa2d8340a338b38d27
# TK : 495113ead51fc5ea96a251e7f976b47b
# TK : 134d54152ba01e9fe88f1a0a5b1ad6be
# TK : 3700547c42da7ae09c24ec6b6aa00a32
# TK : 515559dce339f98bdf41e59cc2312d58
# 0.06
# TK : c9a079dae18d6cf9f45a7b7304a64036
# 0.02
# TK : b51b7c96582c8ced37ab84152d8ecd7f
# TK : a185fa3d8e720a391a9ff8abf586ed36
# 0.02
# TK : a9bbb8c3eb81c1a9f3fbc7898cc594f1
# TK : 3a238c7eab4d6aa07a2d131c7a16b923
# TK : bbe3a7af514a1e93b555a93e1b563527
# TK : 6ce1863c74da54d810832b991f470402
# 0.03
# TK : d4d41627660e5852ffe6006086932f13
# 0.06
# TK : 388446ac842eda819943826ceb9ef7bf
# 0.03
# TK : 2c776cacce0556bc13cad8321e03dd63
# 0.04
# TK : 209191583ccd864db4369c4e9795ac0f
# TK : 69fac9d833a4c83e16118a0f39cc3cff
# TK : 65f1123aec394810d4c120487c8c317f
# TK : 71454e7d4d81c74ab207e23575e47a3c
# 0.03
# TK : b36a1f37f42016168752c5f00ef2a7bb
# TK : 33e61180cbe419148bd8607fdfd71ab0
# TK : d9bcb7184304e0c036f3c0b819aea987
# TK : 71ce7a01c6102f829ee84aaa7053d8a7
# TK : 019549c90fb14deef750ea44726c50ee
# TK : 33de07934db7fd50281e3d07f6926a5d
# TK : f52b30ff99fde36cdbb696e2d4c08157
# TK : 3cddf41bb674e21ec63e5eb6e6e63073
# TK : 70f9a284ab92b4690245d88dd54ae9d9
# 0.03
# TK : e3656d1e40cc16da86de9684ca07c135
# 0.02
# TK : 12c44dfd4e16f6ee5cd99a4a046cd19e
# TK : 3d96be65d05d8a490198a0d78106ff69
# TK : 7340ddb3e24efb80cab692b769a7d5bf
# TK : aa50ec24a88252eb3408208b80d9cb28
# TK : c0f9f87e90a90a5d9e1fc2d72865a15c
# TK : 55d549fdc26434ace4714597d05b0b28
# TK : 9493564625903d10c96f11d7d4338d3d
# 0.03
# TK : 3959ac1b4146e5ded1e6c0b16b963898
# 0.04
# TK : 6104ec939d1e447eee7ba45aabb558c2
# 0.02
# TK : 10918c8f992ba8c9f6589510926be915
# TK : 3fa8c523c0ebb1384edadd691054d6f9
# 0.03
# TK : d7abc67e5bc1da8a9ad0b90c130471a4
# 0.04
# TK : 093dcefd861a12674d31126b4e62a92c
# 0.02
# TK : 769513cd3c8af4b1e1f1c5a3f30bc063
# 0.04
# TK : ea83b4521a09da6ad9839c0cf1ae249a
# 0.03
# TK : f78973a4c91c7c69489dc6d632138ec4
# TK : 7619aa25dae9bc7a483e6614db291f20
# TK : 32acc3021c403ec36c35ff969961334b
# 0.02
# TK : 9e9472d976205d470f9797efec75c498
# 0.04
# TK : bdeec84d4af809377a9fbbea4680e9ac
# TK : b289ec1a263fa1d1cc159d0907650910
# TK : 6a3e8675fbbe2e6dc11a3ad3287ba67a
# TK : 0bb86bb7bb444a8696ab219b71224cd9
# TK : 0af017d145db3f6d136c9f72c841748a
# TK : a2c0ba939bb64dcf758fb7b50684007f
# TK : e546d92e4eecd41e3a30488d40f93113
# TK : baf322b8dfff00f7d0cd6278a07eb874
# TK : d14daa96efac7d301b2cd104000aea1a
# TK : 380ddf4fe6200f6543bfbaf65bbe898d
# 0.03
# TK : eb8506ebf6ee69c10bcf34b35b069adf
# TK : bd48988fe9064dd2a4aa47393248427e
# 0.06
# TK : 16f6a1fd0adc196e96f2de433450bd29
# TK : a6255738df5dc0a93b693b4319db6893
# 0.03
# TK : 7d611223ad14d3e7249f35e46c7ef2e4
# TK : 7710a67ba7469141e5297fce73976191
# 0.04
# TK : 740398a00ae8bc927ebf51fc38bc519e
# 0.04
# TK : f96ee891e48293c810c3b287383658d6
# 0.02
# TK : a2d435c3d11ec5f71fa6dbe483b8f972
# TK : 3c82e739502d8a206ada846c451ae722
# 0.02
# TK : 9180a23fce98523505bfb691da14aa24
# 0.03
# TK : e28a0fe70718a7a7152d352943ed23cd
# 0.02
# TK : 63cfea042dc968d0c14a66dbc574492d
# 0.03
# TK : 906eb2c30825bd5140a99b1adc6f1d67
# 0.05
# TK : 929478f4a00c790d27d72936e9e810b2
# TK : e6188248650b1ca8b807448e71a96aa4
# TK : 427e5da2732c79dfa6b8719b715439b1
# TK : 28604ea17490794fcd8bda89d7e7e7bf
# 0.04
# TK : e70d86668e09f5e07f7b37b2aafe8158
# 0.03
# TK : 5827c670fb825a85ed43d171e7d77328
# 0.02
# TK : 9ca7733cd3d49f6c5d98ed2f0b21b6a8
# 0.02
# TK : dcfd4dbf92dae10daed695da0a79c697
# 0.04
# obs
# Counter({'d4d41627660e5852ffe6006086932f13': 1, 'bd48988fe9064dd2a4aa47393248427e': 1, '906eb2c30825bd5140a99b1adc6f1d67': 1, '815b1c6810e3203e2f5b6d1ca91bd84a': 1, '515559dce339f98bdf41e59cc2312d58': 1})
# TK : d4d41627660e5852ffe6006086932f13
# 0.06
# TK : bd48988fe9064dd2a4aa47393248427e
# 0.05
# TK : 906eb2c30825bd5140a99b1adc6f1d67
# 0.04
# TK : 815b1c6810e3203e2f5b6d1ca91bd84a
# 0.02
# TK : 515559dce339f98bdf41e59cc2312d58
# 0.05
# descr
# Counter({'dcfd4dbf92dae10daed695da0a79c697': 1, 'd4d41627660e5852ffe6006086932f13': 1, '6d67ff9607e69d8022ded44ce59696ad': 1, '093dcefd861a12674d31126b4e62a92c': 1, '3959ac1b4146e5ded1e6c0b16b963898': 1, 'a6255738df5dc0a93b693b4319db6893': 1})
# TK : dcfd4dbf92dae10daed695da0a79c697
# 0.05
# TK : d4d41627660e5852ffe6006086932f13
# 0.06
# TK : 6d67ff9607e69d8022ded44ce59696ad
# 0.03
# TK : 093dcefd861a12674d31126b4e62a92c
# 0.03
# TK : 3959ac1b4146e5ded1e6c0b16b963898
# 0.05
# TK : a6255738df5dc0a93b693b4319db6893
# 0.04

# %%
for x in uniques_attr(assert_attr_subs, pmrod):
    draw_graph(x)

# %%
sim_diff = sim_diff_attr(assert_gphs, prop_gphs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-397afb620c98> in <module>
# ----> 1 sim_diff = sim_diff_attr(assert_gphs, prop_gphs)
#
# NameError: name 'sim_diff_attr' is not defined

# %%
nx.is_isomorphic(cop, prop_gphs[0])

# %%
def is_spe(objs, othertypesobjs):
    """
     returns true if the set of objs is specific (not appears in other types objs)
    """
    isspe = True
    for obj in objs:
        if obj in othertypesobjs:
            isspe = False
            break
    return isspe

# %%
args_per_type_gspan_out["proposal"][1]

# %% [markdown]
# ## Distrib all lengths

# %%
#all_lens = [y for y in types_lens.values() for sublist in x]
all_lens = [item for sublist in types_lens.values() for item in sublist]

# %%
Counter(all_lens)
